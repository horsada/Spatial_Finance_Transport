# %% [markdown]
# # MMDetCV

# %%
# !git clone https://github.com/fcakyon/small-object-detection-benchmark.git
# Out:
# Cloning into 'small-object-detection-benchmark'...
# remote: Enumerating objects: 347, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 347 (delta 145), reused 124 (delta 123), pack-reused 184
# Receiving objects: 100% (347/347), 76.20 KiB | 5.44 MiB/s, done.
# Resolving deltas: 100% (213/213), done.

# %%
#!pip install -r /content/small-object-detection-benchmark/requirements.txt

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git
# Out:
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 35266, done.
# remote: Total 35266 (delta 0), reused 0 (delta 0), pack-reused 35266
# Receiving objects: 100% (35266/35266), 47.19 MiB | 31.71 MiB/s, done.
# Resolving deltas: 100% (24900/24900), done.

# %%
# !pip install sahi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sahi
#   Downloading sahi-0.11.13-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 2.9 MB/s eta 0:00:00
# Collecting click==8.0.4
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.9/dist-packages (from sahi) (4.65.0)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from sahi) (2.0.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from sahi) (6.0)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow>=8.2.0 in /usr/local/lib/python3.9/dist-packages (from sahi) (8.4.0)
# Requirement already satisfied: opencv-python>=4.2.0.32 in /usr/local/lib/python3.9/dist-packages (from sahi) (4.7.0.72)
# Collecting pybboxes==0.1.6
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from sahi) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pybboxes==0.1.6->sahi) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from fire->sahi) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from fire->sahi) (2.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (2.0.12)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=b08c4a34aa7d45ccb7d0f098f753d4f6f86655e1621066c16b520d5bebe09721
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# Installing collected packages: terminaltables, pybboxes, fire, click, sahi
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
# Successfully installed click-8.0.4 fire-0.5.0 pybboxes-0.1.6 sahi-0.11.13 terminaltables-3.1.10

# %% [markdown]
# ## Imports

# %%
# !pip install mmengine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mmengine
#   Downloading mmengine-0.7.2-py3-none-any.whl (366 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.9/366.9 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmengine) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from mmengine) (2.2.0)
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 23.7 MB/s eta 0:00:00
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from mmengine) (13.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.9/dist-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (8.4.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine) (2.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmengine) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Installing collected packages: yapf, addict, mmengine
# Successfully installed addict-2.4.0 mmengine-0.7.2 yapf-0.32.0

# %%
# !pip install mmcv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mmcv
#   Downloading mmcv-2.0.0.tar.gz (473 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.2/473.2 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: addict in /usr/local/lib/python3.9/dist-packages (from mmcv) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from mmcv) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmcv) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from mmcv) (23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from mmcv) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from mmcv) (6.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.9/dist-packages (from mmcv) (0.32.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv) (3.7.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv) (2.2.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv) (13.3.3)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv) (4.7.0.72)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv) (1.4.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine>=0.2.0->mmcv) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine>=0.2.0->mmcv) (2.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmengine>=0.2.0->mmcv) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine>=0.2.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv) (1.16.0)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-2.0.0-cp39-cp39-linux_x86_64.whl size=41520094 sha256=17dd9b8aa59c83312580922dcdf2e196fc3e9ce77fc668ff57932db6a2401a61
#   Stored in directory: /root/.cache/pip/wheels/1b/64/bd/12c67416b3f5113fe4e4be4eb04ec78d1110c8b4d7bc56e7ce
# Successfully built mmcv
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0

# %%
# !pip install mmdet==3.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mmdet==3.0.0
#   Downloading mmdet-3.0.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: shapely in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (1.10.1)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (3.1.10)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (3.7.1)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.9/dist-packages (from mmdet==3.0.0) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmdet==3.0.0) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmdet==3.0.0) (3.15.0)
# Installing collected packages: mmdet
# Successfully installed mmdet-3.0.0

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.14.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (5.9.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.19.1-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb) (4.5.0)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb) (6.0)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb) (67.6.1)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (8.0.4)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=a02617419531f32c9e78e201800e74073ae32ea1e2b3926dd2ece77a30ecd6a3
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.19.1 setproctitle-1.3.2 smmap-5.0.0 wandb-0.14.2

# %%
# !pip install sahi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sahi in /usr/local/lib/python3.9/dist-packages (0.11.13)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.9/dist-packages (from sahi) (3.1.10)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.9/dist-packages (from sahi) (4.65.0)
# Requirement already satisfied: pillow>=8.2.0 in /usr/local/lib/python3.9/dist-packages (from sahi) (8.4.0)
# Requirement already satisfied: opencv-python>=4.2.0.32 in /usr/local/lib/python3.9/dist-packages (from sahi) (4.7.0.72)
# Requirement already satisfied: fire in /usr/local/lib/python3.9/dist-packages (from sahi) (0.5.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from sahi) (6.0)
# Requirement already satisfied: pybboxes==0.1.6 in /usr/local/lib/python3.9/dist-packages (from sahi) (0.1.6)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from sahi) (2.0.1)
# Requirement already satisfied: click==8.0.4 in /usr/local/lib/python3.9/dist-packages (from sahi) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from sahi) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pybboxes==0.1.6->sahi) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from fire->sahi) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from fire->sahi) (2.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->sahi) (1.26.15)

# %%
# arrange an instance segmentation model for test
from sahi.utils.mmdet import (
    download_mmdet_retinanet_model,
    download_mmdet_cascade_mask_rcnn_model,
    download_mmdet_config,
)

# import required functions, classes
from sahi import AutoDetectionModel
from sahi.utils.cv import read_image
from sahi.utils.file import download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict
from IPython.display import Image

import fire
from sahi.scripts.slice_coco import slice
from tqdm import tqdm

# %%
import random
from collections import defaultdict
from pathlib import Path
from typing import Dict, List

import fire
import numpy as np
from PIL import Image
from sahi.utils.coco import Coco, CocoAnnotation, CocoCategory, CocoImage
from sahi.utils.file import load_json, save_json
from tqdm import tqdm
import mmcv, mmengine, mmdet
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
#from mmdet.datasets import build_dataset
#from mmdet.models import build_detector
#from mmdet.apis import train_detector
import glob
import cv2
import shutil
import random
import os.path as osp
import json
import mmcv
import re
import xml.etree.ElementTree as ET
from typing import Dict, List

# %% [markdown]
# ## Global Variables

# %%
XVIEW_TRAIN_IMAGES_DIR = "/content/xView/train_images"
XVIEW_TRAIN_GEOJSON_PATH = "/content/xView/xView_train.geojson"
XVIEW_CLASS_LABELS_PATH = "/content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/xview_class_labels.txt"
XVIEW_JSON_CATEGORY_MAPPING_PATH = "/content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/category_id_mapping.json"
XVIEW_OUTPUT_DIR = "/content/xView"

# %%
SLICE_SIZE_LIST = [512]
OVERLAP_RATIO_LIST = [0.25]
IGNORE_NEGATIVE_SAMPLES = False

XVIEW_IMAGES_DIR = "/content/xView/train_images"
XVIEW_TRAIN_GEOJSON_PATH = '/content/xView/train.json'
XVIEW_VAL_GEOJSON_PATH = "/content/xView/val.json"
XVIEW_SLICE_TRAIN_OUTPUT_DIR = '/content/xView_slice_train'
XVIEW_SLICE_VAL_OUTPUT_DIR = '/content/xView_slice_val'

# %% [markdown]
# ## Helper Functions

# %%
def copy_file(source_file, target_dir):
    """
    Copies a file from source file path to target directory path.

    Args:
        source_file (str): Path to the source file.
        target_dir (str): Path to the target directory.

    Returns:
        str: Path to the copied file in the target directory.
    """
    # Extract the filename from the source file path
    filename = os.path.basename(source_file)
    # Construct the target file path by joining the target directory and filename
    target_file = os.path.join(target_dir, filename)
    # Copy the file from source to target
    shutil.copy2(source_file, target_file)
    return target_file

# %%
def move_files(source_dir, destination_dir):
    """
    Move all files from the source directory to the destination directory.

    Args:
        source_dir (str): Path to the source directory.
        destination_dir (str): Path to the destination directory.

    Returns:
        None
    """
    # Check if source directory exists
    if not os.path.exists(source_dir):
        print(f"Source directory '{source_dir}' does not exist.")
        return

    # Check if destination directory exists, if not create it
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # Get all files in the source directory
    files = os.listdir(source_dir)

    # Loop through all files and move them to the destination directory
    for file in files:
        source_file = os.path.join(source_dir, file)
        destination_file = os.path.join(destination_dir, file)
        shutil.move(source_file, destination_file)
        print(f"Moved file '{file}' to '{destination_dir}'.")

    print("All files moved successfully.")

# %%
def get_labels(fname):
    """
    Gets label data from a geojson label file
    Args:
        fname: file path to an xView geojson label file
    Output:
        Returns three arrays: coords, chips, and classes corresponding to the
            coordinates, file-names, and classes for each ground truth.
    Modified from https://github.com/DIUx-xView.
    """
    data = load_json(fname)

    coords = np.zeros((len(data["features"]), 4))
    chips = np.zeros((len(data["features"])), dtype="object")
    classes = np.zeros((len(data["features"])))
    image_name_to_annotation_ind = defaultdict(list)

    for i in tqdm(range(len(data["features"])), "Parsing xView data"):
        if data["features"][i]["properties"]["bounds_imcoords"] != []:
            b_id = data["features"][i]["properties"]["image_id"]
            # https://github.com/DIUx-xView/xView1_baseline/issues/3
            if b_id == "1395.tif":
                continue
            val = np.array(
                [
                    int(num)
                    for num in data["features"][i]["properties"][
                        "bounds_imcoords"
                    ].split(",")
                ]
            )
            chips[i] = b_id
            classes[i] = data["features"][i]["properties"]["type_id"]

            image_name_to_annotation_ind[b_id].append(i)

            if val.shape[0] != 4:
                print("Issues at %d!" % i)
            else:
                coords[i] = val
        else:
            chips[i] = "None"

    return coords, chips, classes, image_name_to_annotation_ind

# %%
def get_ordered_image_name_list(image_name_to_annotation_ind: Dict):
    image_name_list: List[str] = list(image_name_to_annotation_ind.keys())

    def get_image_ind(image_name: str):
        return int(image_name.split(".")[0])

    image_name_list.sort(key=get_image_ind)

    return image_name_list

# %%
def xview_to_coco(
    train_images_dir,
    train_geojson_path,
    output_dir,
    train_split_rate=0.75,
    category_id_remapping=None,
):
    """
    Converts visdrone-det annotations into coco annotation.
    Args:
        train_images_dir: str
            'train_images' folder directory
        train_geojson_path: str
            'xView_train.geojson' file path
        output_dir: str
            Output folder directory
        train_split_rate: bool
            Train split ratio
        category_id_remapping: dict
            Used for selecting desired category ids and mapping them.
            If not provided, xView mapping will be used.
            format: str(id) to str(id)
    """

    # init vars
    category_id_to_name = {}
    with open(XVIEW_CLASS_LABELS_PATH, encoding="utf8") as f:
        lines = f.readlines()
    for line in lines:
        category_id = line.split(":")[0]
        category_name = line.split(":")[1].replace("\n", "")
        category_id_to_name[category_id] = category_name

    if category_id_remapping is None:
        category_id_remapping = load_json(XVIEW_JSON_CATEGORY_MAPPING_PATH)
    category_id_remapping

    # init coco object
    coco = Coco()
    # append categories
    for category_id, category_name in category_id_to_name.items():
        if category_id in category_id_remapping.keys():
            remapped_category_id = category_id_remapping[category_id]
            coco.add_category(
                CocoCategory(id=int(remapped_category_id), name=category_name)
            )

    # parse xview data
    coords, chips, classes, image_name_to_annotation_ind = get_labels(
        train_geojson_path
    )
    image_name_list = get_ordered_image_name_list(image_name_to_annotation_ind)

    # convert xView data to COCO format
    for image_name in tqdm(image_name_list, "Converting xView data into COCO format"):
        # create coco image object
        width, height = Image.open(Path(train_images_dir) / image_name).size
        coco_image = CocoImage(file_name=image_name, height=height, width=width)

        annotation_ind_list = image_name_to_annotation_ind[image_name]

        # iterate over image annotations
        for annotation_ind in annotation_ind_list:
            bbox = coords[annotation_ind].tolist()
            category_id = str(int(classes[annotation_ind].item()))
            coco_bbox = [bbox[0], bbox[1], bbox[2] - bbox[0], bbox[3] - bbox[1]]
            if category_id in category_id_remapping.keys():
                category_name = category_id_to_name[category_id]
                remapped_category_id = category_id_remapping[category_id]
            else:
                continue
            # create coco annotation and append it to coco image
            coco_annotation = CocoAnnotation(
                bbox=coco_bbox,
                category_id=int(remapped_category_id),
                category_name=category_name,
            )
            if coco_annotation.area > 0:
                coco_image.add_annotation(coco_annotation)
        coco.add_image(coco_image)

    result = coco.split_coco_as_train_val(train_split_rate=train_split_rate)

    train_json_path = Path(output_dir) / "train.json"
    val_json_path = Path(output_dir) / "val.json"
    save_json(data=result["train_coco"].json, save_path=train_json_path)
    save_json(data=result["val_coco"].json, save_path=val_json_path)

# %%
def slice_xview(image_dir: str, dataset_json_path: str, output_dir: str):
    total_run = len(SLICE_SIZE_LIST) * len(OVERLAP_RATIO_LIST)
    current_run = 1
    for slice_size in SLICE_SIZE_LIST:
        for overlap_ratio in OVERLAP_RATIO_LIST:
            tqdm.write(
                f"{current_run} of {total_run}: slicing for slice_size={slice_size}, overlap_ratio={overlap_ratio}"
            )
            slice(
                image_dir=image_dir,
                dataset_json_path=dataset_json_path,
                output_dir=output_dir,
                slice_size=slice_size,
                overlap_ratio=overlap_ratio,
            )
            current_run += 1

# %% [markdown]
# ## xView Dataset

# %% [markdown]
# ### tar files

# %%
# %cd ~/../content/
# !wget --header="Host: d307kc0mrhucc3.cloudfront.net" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7" --header="Accept-Language: en-US,en;q=0.9,ar;q=0.8,zh-CN;q=0.7,zh;q=0.6" --header="Referer: https://challenge.xviewdataset.org/" "https://d307kc0mrhucc3.cloudfront.net/train_images.tgz?Expires=1681572244&Signature=PMMVS7EwooBOdrfVA1NHIBHr5v~McX97MiHt4mnWDAg11vxHw2Cg1OL5iqT0pK3XOXtOJLmNIysRmDaFx3SHMGD9QVgvJ4avu3MQoqfihBPcN2E9yED5tc45Zq1sxRIZvtHhnnyGjJYc58vg0E-z5iSRib0xXIigNrp7Y6nE1YyMHSgW~xQNy92H9IAHE-s0DuT5C7G56RWGlLxeZQ8dyXzwMqCrv1niAW8JQmctDDl2HsiM6VVBi3dusMfEyhudYaMnN~Z1RVEIlER9FnewhN0kVg5Se0hlCdsXPiVhzzRjWPBDyO08EGGxWzxG3LfX0Lcc8f0VvYDEsA58dwe3uw__&Key-Pair-Id=APKAIKGDJB5C3XUL2DXQ" -c -O 'train_images.tgz'
# !wget --header="Host: d307kc0mrhucc3.cloudfront.net" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7" --header="Accept-Language: en-US,en;q=0.9,ar;q=0.8,zh-CN;q=0.7,zh;q=0.6" --header="Referer: https://challenge.xviewdataset.org/" "https://d307kc0mrhucc3.cloudfront.net/train_labels.tgz?Expires=1681572244&Signature=FQ2Zcccm8FekPwudjeS3Ycebvu9OXc2ten1g9Mwg7~ifV-zL2tYZ696Lx-pwsBbNQySAl0EdXW8e0z5pseJ-QAZVZ94~E6VRjt4R1K1Izy806Z8R8e1HZLCakRUr9ilTj8gE~R31NNrtE3QXNlwCtHtfZEIfxULK92KQ-WYZYJWpCwUFODaaZylG~zZG8yiNuz38y4gfQDeT1GMSt-geXbDUvlnn0g56P5A2BGNOFJlM9qD-EyC26rXcjFWiI8-EwLzf96OLnh1AmzEHNKbYgAsEdFedKwAUfAIs73Cq7Y4Ik2OJWOtWtrjnroPwK4Mv8ZKmDgKnb6OkukHR9JoXcA__&Key-Pair-Id=APKAIKGDJB5C3XUL2DXQ" -c -O 'train_labels.tgz'
# !wget --header="Host: d307kc0mrhucc3.cloudfront.net" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.
# Resolving d307kc0mrhucc3.cloudfront.net (d307kc0mrhucc3.cloudfront.net)... 99.84.245.129, 99.84.245.61, 99.84.245.80, ...
# Connecting to d307kc0mrhucc3.cloudfront.net (d307kc0mrhucc3.cloudfront.net)|99.84.245.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48950328 (47M) [application/gzip]
# Saving to: ‘train_labels.tgz’
#
# train_labels.tgz    100%[===================>]  46.68M  36.5MB/s    in 1.3s
#
# 2023-04-15 09:47:28 (36.5 MB/s) - ‘train_labels.tgz’ saved [48950328/48950328]
#
# --2023-04-15 09:47:28--  https://d307kc0mrhucc3.cloudfront.net/val_images.tgz?Expires=1681572244&Signature=kqnDbVn83yBa1g6nder7ULZqLGpZQhewFTKKH0D3RFyZm8iDzvI0kjqS-fBu1J-Ncq7iNonnPp5Fbsrdmp32AA5kjIyQvDqnG3TMn~PNqPIB~d1ptD1TiXChC92iBxOACvPeWVpqlCCdPnG6UE1bVGfyrXdy~5eGreJf-38w6eIikETvn6DHAJQbo~BiGQAZkIxVrrmskvOUI5~-FRJZDBT9Vj805wyaKuAf8-xVoZ4PK9Jnbe8c5XGKppNFlfdUAcaDlhYrIWS-dh7ql0xwGaJOMhcenoiLUHnE2AGuV7FmeM01P49wU0mew~5KSBThl1SbdW8sYF4Ruaww6XtVuw__&Key-Pair-Id=APKAIKGDJB5C3XUL2DXQ
# Resolving d307kc0mrhucc3.cloudfront.net (d307kc0mrhucc3.cloudfront.net)... 99.84.245.129, 99.84.245.61, 99.84.245.80, ...
# Connecting to d307kc0mrhucc3.cloudfront.net (d307kc0mrhucc3.cloudfront.net)|99.84.245.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5258921432 (4.9G) [application/gzip]
# Saving to: ‘val_images.tgz’
#
# val_images.tgz      100%[===================>]   4.90G   146MB/s    in 35s
#
# 2023-04-15 09:48:03 (144 MB/s) - ‘val_images.tgz’ saved [5258921432/5258921432]

# %%
# %cd ~/../content/
# %mkdir xView/
# !tar -xvzf "train_images.tgz" -C "xView/"
# !tar -xvzf "train_labels.tgz" -C "xView/"
# !tar -xvzf "val_images.tgz" -C "xView/"     #[run this cell to extract tar.gz files]
# Out:
# /content
# mkdir: cannot create directory ‘xView/’: File exists
# ./train_images/
# ./train_images/10.tif
# ./train_images/._100.tif
# ./train_images/100.tif
# ./train_images/._102.tif
# ./train_images/102.tif
# ./train_images/1036.tif
# ./train_images/1037.tif
# ./train_images/104.tif
# ./train_images/1042.tif
# ./train_images/1044.tif
# ./train_images/1046.tif
# ./train_images/1048.tif
# ./train_images/1049.tif
# ./train_images/105.tif
# ./train_images/1050.tif
# ./train_images/1051.tif
# ./train_images/1052.tif
# ./train_images/1053.tif
# ./train_images/1056.tif
# ./train_images/1058.tif
# ./train_images/106.tif
# ./val_images/965.tif
# ./val_images/967.tif
# ./val_images/978.tif
# ./val_images/98.tif
# ./val_images/981.tif
# ./val_images/985.tif
# ./val_images/995.tif

# %% [markdown]
# ### Move train and val to same dir

# %%
# Example usage
source_dir = "/content/xView/val_images"
destination_dir = "/content/xView/train_images"
move_files(source_dir, destination_dir)
# Out:
# Moved file '2575.tif' to '/content/xView/train_images'.
# Moved file '221.tif' to '/content/xView/train_images'.
# Moved file '2529.tif' to '/content/xView/train_images'.
# Moved file '566.tif' to '/content/xView/train_images'.
# Moved file '995.tif' to '/content/xView/train_images'.
# Moved file '1082.tif' to '/content/xView/train_images'.
# Moved file '1402.tif' to '/content/xView/train_images'.
# Moved file '2620.tif' to '/content/xView/train_images'.
# Moved file '1794.tif' to '/content/xView/train_images'.
# Moved file '577.tif' to '/content/xView/train_images'.
# Moved file '1800.tif' to '/content/xView/train_images'.
# Moved file '950.tif' to '/content/xView/train_images'.
# Moved file '319.tif' to '/content/xView/train_images'.
# Moved file '1064.tif' to '/content/xView/train_images'.
# Moved file '1358.tif' to '/content/xView/train_images'.
# Moved file '259.tif' to '/content/xView/train_images'.
# Moved file '965.tif' to '/content/xView/train_images'.
# Moved file '1510.tif' to '/content/xView/train_images'.
# Moved file '654.tif' to '/content/xView/train_images'.
# Moved file '967.tif' to '/content/xView/train_images'.
# Moved file '961.tif' to '/content/xView/train_images'.
# Moved file '2403.tif' to '/content/xView/train_images'.
# Moved file '1475.tif' to '/content/xView/train_images'.
# Moved file '2392.tif' to '/content/xView/train_images'.
# Moved file '2016.tif' to '/content/xView/train_images'.
# Moved file '396.tif' to '/content/xView/train_images'.
# Moved file '2522.tif' to '/content/xView/train_images'.
# Moved file '1134.tif' to '/content/xView/train_images'.
# Moved file '1194.tif' to '/content/xView/train_images'.
# Moved file '2449.tif' to '/content/xView/train_images'.
# Moved file '586.tif' to '/content/xView/train_images'.
# Moved file '2024.tif' to '/content/xView/train_images'.
# Moved file '2554.tif' to '/content/xView/train_images'.
# Moved file '2300.tif' to '/content/xView/train_images'.
# Moved file '1333.tif' to '/content/xView/train_images'.
# Moved file '1060.tif' to '/content/xView/train_images'.
# Moved file '2491.tif' to '/content/xView/train_images'.
# Moved file '1917.tif' to '/content/xView/train_images'.
# Moved file '947.tif' to '/content/xView/train_images'.
# Moved file '2178.tif' to '/content/xView/train_images'.
# Moved file '1267.tif' to '/content/xView/train_images'.
# Moved file '656.tif' to '/content/xView/train_images'.
# Moved file '1359.tif' to '/content/xView/train_images'.
# Moved file '909.tif' to '/content/xView/train_images'.
# Moved file '1073.tif' to '/content/xView/train_images'.
# Moved file '944.tif' to '/content/xView/train_images'.
# Moved file '1122.tif' to '/content/xView/train_images'.
# Moved file '35.tif' to '/content/xView/train_images'.
# Moved file '2613.tif' to '/content/xView/train_images'.
# Moved file '1038.tif' to '/content/xView/train_images'.
# Moved file '809.tif' to '/content/xView/train_images'.
# Moved file '2127.tif' to '/content/xView/train_images'.
# Moved file '261.tif' to '/content/xView/train_images'.
# Moved file '1811.tif' to '/content/xView/train_images'.
# Moved file '1566.tif' to '/content/xView/train_images'.
# Moved file '1681.tif' to '/content/xView/train_images'.
# Moved file '1814.tif' to '/content/xView/train_images'.
# Moved file '2321.tif' to '/content/xView/train_images'.
# Moved file '147.tif' to '/content/xView/train_images'.
# Moved file '93.tif' to '/content/xView/train_images'.
# Moved file '2473.tif' to '/content/xView/train_images'.
# Moved file '1909.tif' to '/content/xView/train_images'.
# Moved file '1071.tif' to '/content/xView/train_images'.
# Moved file '241.tif' to '/content/xView/train_images'.
# Moved file '2363.tif' to '/content/xView/train_images'.
# Moved file '1138.tif' to '/content/xView/train_images'.
# Moved file '1905.tif' to '/content/xView/train_images'.
# Moved file '7.tif' to '/content/xView/train_images'.
# Moved file '1360.tif' to '/content/xView/train_images'.
# Moved file '96.tif' to '/content/xView/train_images'.
# Moved file '1234.tif' to '/content/xView/train_images'.
# Moved file '2342.tif' to '/content/xView/train_images'.
# Moved file '2500.tif' to '/content/xView/train_images'.
# Moved file '710.tif' to '/content/xView/train_images'.
# Moved file '2570.tif' to '/content/xView/train_images'.
# Moved file '2038.tif' to '/content/xView/train_images'.
# Moved file '578.tif' to '/content/xView/train_images'.
# Moved file '2393.tif' to '/content/xView/train_images'.
# Moved file '882.tif' to '/content/xView/train_images'.
# Moved file '1872.tif' to '/content/xView/train_images'.
# Moved file '178.tif' to '/content/xView/train_images'.
# Moved file '2604.tif' to '/content/xView/train_images'.
# Moved file '1177.tif' to '/content/xView/train_images'.
# Moved file '583.tif' to '/content/xView/train_images'.
# Moved file '357.tif' to '/content/xView/train_images'.
# Moved file '1816.tif' to '/content/xView/train_images'.
# Moved file '2508.tif' to '/content/xView/train_images'.
# Moved file '985.tif' to '/content/xView/train_images'.
# Moved file '1843.tif' to '/content/xView/train_images'.
# Moved file '1213.tif' to '/content/xView/train_images'.
# Moved file '301.tif' to '/content/xView/train_images'.
# Moved file '1040.tif' to '/content/xView/train_images'.
# Moved file '589.tif' to '/content/xView/train_images'.
# Moved file '1075.tif' to '/content/xView/train_images'.
# Moved file '201.tif' to '/content/xView/train_images'.
# Moved file '1750.tif' to '/content/xView/train_images'.
# Moved file '1742.tif' to '/content/xView/train_images'.
# Moved file '912.tif' to '/content/xView/train_images'.
# Moved file '1952.tif' to '/content/xView/train_images'.
# Moved file '1097.tif' to '/content/xView/train_images'.
# Moved file '2517.tif' to '/content/xView/train_images'.
# Moved file '636.tif' to '/content/xView/train_images'.
# Moved file '668.tif' to '/content/xView/train_images'.
# Moved file '1670.tif' to '/content/xView/train_images'.
# Moved file '207.tif' to '/content/xView/train_images'.
# Moved file '376.tif' to '/content/xView/train_images'.
# Moved file '1254.tif' to '/content/xView/train_images'.
# Moved file '1464.tif' to '/content/xView/train_images'.
# Moved file '32.tif' to '/content/xView/train_images'.
# Moved file '667.tif' to '/content/xView/train_images'.
# Moved file '2336.tif' to '/content/xView/train_images'.
# Moved file '1401.tif' to '/content/xView/train_images'.
# Moved file '447.tif' to '/content/xView/train_images'.
# Moved file '2537.tif' to '/content/xView/train_images'.
# Moved file '913.tif' to '/content/xView/train_images'.
# Moved file '2116.tif' to '/content/xView/train_images'.
# Moved file '2100.tif' to '/content/xView/train_images'.
# Moved file '628.tif' to '/content/xView/train_images'.
# Moved file '1426.tif' to '/content/xView/train_images'.
# Moved file '350.tif' to '/content/xView/train_images'.
# Moved file '1434.tif' to '/content/xView/train_images'.
# Moved file '687.tif' to '/content/xView/train_images'.
# Moved file '554.tif' to '/content/xView/train_images'.
# Moved file '891.tif' to '/content/xView/train_images'.
# Moved file '2622.tif' to '/content/xView/train_images'.
# Moved file '358.tif' to '/content/xView/train_images'.
# Moved file '365.tif' to '/content/xView/train_images'.
# Moved file '485.tif' to '/content/xView/train_images'.
# Moved file '2351.tif' to '/content/xView/train_images'.
# Moved file '490.tif' to '/content/xView/train_images'.
# Moved file '1866.tif' to '/content/xView/train_images'.
# Moved file '1746.tif' to '/content/xView/train_images'.
# Moved file '754.tif' to '/content/xView/train_images'.
# Moved file '1578.tif' to '/content/xView/train_images'.
# Moved file '1997.tif' to '/content/xView/train_images'.
# Moved file '108.tif' to '/content/xView/train_images'.
# Moved file '359.tif' to '/content/xView/train_images'.
# Moved file '2167.tif' to '/content/xView/train_images'.
# Moved file '1207.tif' to '/content/xView/train_images'.
# Moved file '27.tif' to '/content/xView/train_images'.
# Moved file '332.tif' to '/content/xView/train_images'.
# Moved file '2023.tif' to '/content/xView/train_images'.
# Moved file '1521.tif' to '/content/xView/train_images'.
# Moved file '1996.tif' to '/content/xView/train_images'.
# Moved file '2549.tif' to '/content/xView/train_images'.
# Moved file '1652.tif' to '/content/xView/train_images'.
# Moved file '1955.tif' to '/content/xView/train_images'.
# Moved file '780.tif' to '/content/xView/train_images'.
# Moved file '1159.tif' to '/content/xView/train_images'.
# Moved file '1595.tif' to '/content/xView/train_images'.
# Moved file '367.tif' to '/content/xView/train_images'.
# Moved file '431.tif' to '/content/xView/train_images'.
# Moved file '1258.tif' to '/content/xView/train_images'.
# Moved file '12.tif' to '/content/xView/train_images'.
# Moved file '1882.tif' to '/content/xView/train_images'.
# Moved file '2429.tif' to '/content/xView/train_images'.
# Moved file '368.tif' to '/content/xView/train_images'.
# Moved file '297.tif' to '/content/xView/train_images'.
# Moved file '1522.tif' to '/content/xView/train_images'.
# Moved file '122.tif' to '/content/xView/train_images'.
# Moved file '2047.tif' to '/content/xView/train_images'.
# Moved file '1846.tif' to '/content/xView/train_images'.
# Moved file '2415.tif' to '/content/xView/train_images'.
# Moved file '2556.tif' to '/content/xView/train_images'.
# Moved file '1933.tif' to '/content/xView/train_images'.
# Moved file '770.tif' to '/content/xView/train_images'.
# Moved file '1554.tif' to '/content/xView/train_images'.
# Moved file '1069.tif' to '/content/xView/train_images'.
# Moved file '11.tif' to '/content/xView/train_images'.
# Moved file '1819.tif' to '/content/xView/train_images'.
# Moved file '98.tif' to '/content/xView/train_images'.
# Moved file '1765.tif' to '/content/xView/train_images'.
# Moved file '2129.tif' to '/content/xView/train_images'.
# Moved file '592.tif' to '/content/xView/train_images'.
# Moved file '2132.tif' to '/content/xView/train_images'.
# Moved file '2464.tif' to '/content/xView/train_images'.
# Moved file '2621.tif' to '/content/xView/train_images'.
# Moved file '664.tif' to '/content/xView/train_images'.
# Moved file '690.tif' to '/content/xView/train_images'.
# Moved file '313.tif' to '/content/xView/train_images'.
# Moved file '963.tif' to '/content/xView/train_images'.
# Moved file '925.tif' to '/content/xView/train_images'.
# Moved file '1813.tif' to '/content/xView/train_images'.
# Moved file '2428.tif' to '/content/xView/train_images'.
# Moved file '1116.tif' to '/content/xView/train_images'.
# Moved file '782.tif' to '/content/xView/train_images'.
# Moved file '2427.tif' to '/content/xView/train_images'.
# Moved file '746.tif' to '/content/xView/train_images'.
# Moved file '1951.tif' to '/content/xView/train_images'.
# Moved file '949.tif' to '/content/xView/train_images'.
# Moved file '2378.tif' to '/content/xView/train_images'.
# Moved file '2340.tif' to '/content/xView/train_images'.
# Moved file '1326.tif' to '/content/xView/train_images'.
# Moved file '2307.tif' to '/content/xView/train_images'.
# Moved file '1474.tif' to '/content/xView/train_images'.
# Moved file '2404.tif' to '/content/xView/train_images'.
# Moved file '2496.tif' to '/content/xView/train_images'.
# Moved file '2579.tif' to '/content/xView/train_images'.
# Moved file '1728.tif' to '/content/xView/train_images'.
# Moved file '1148.tif' to '/content/xView/train_images'.
# Moved file '299.tif' to '/content/xView/train_images'.
# Moved file '1308.tif' to '/content/xView/train_images'.
# Moved file '700.tif' to '/content/xView/train_images'.
# Moved file '632.tif' to '/content/xView/train_images'.
# Moved file '1903.tif' to '/content/xView/train_images'.
# Moved file '2120.tif' to '/content/xView/train_images'.
# Moved file '2349.tif' to '/content/xView/train_images'.
# Moved file '2077.tif' to '/content/xView/train_images'.
# Moved file '941.tif' to '/content/xView/train_images'.
# Moved file '731.tif' to '/content/xView/train_images'.
# Moved file '2146.tif' to '/content/xView/train_images'.
# Moved file '1470.tif' to '/content/xView/train_images'.
# Moved file '1161.tif' to '/content/xView/train_images'.
# Moved file '239.tif' to '/content/xView/train_images'.
# Moved file '483.tif' to '/content/xView/train_images'.
# Moved file '827.tif' to '/content/xView/train_images'.
# Moved file '1117.tif' to '/content/xView/train_images'.
# Moved file '576.tif' to '/content/xView/train_images'.
# Moved file '673.tif' to '/content/xView/train_images'.
# Moved file '1944.tif' to '/content/xView/train_images'.
# Moved file '2480.tif' to '/content/xView/train_images'.
# Moved file '511.tif' to '/content/xView/train_images'.
# Moved file '1471.tif' to '/content/xView/train_images'.
# Moved file '1062.tif' to '/content/xView/train_images'.
# Moved file '412.tif' to '/content/xView/train_images'.
# Moved file '1098.tif' to '/content/xView/train_images'.
# Moved file '2357.tif' to '/content/xView/train_images'.
# Moved file '2001.tif' to '/content/xView/train_images'.
# Moved file '2135.tif' to '/content/xView/train_images'.
# Moved file '564.tif' to '/content/xView/train_images'.
# Moved file '539.tif' to '/content/xView/train_images'.
# Moved file '1804.tif' to '/content/xView/train_images'.
# Moved file '1414.tif' to '/content/xView/train_images'.
# Moved file '981.tif' to '/content/xView/train_images'.
# Moved file '718.tif' to '/content/xView/train_images'.
# Moved file '676.tif' to '/content/xView/train_images'.
# Moved file '666.tif' to '/content/xView/train_images'.
# Moved file '1054.tif' to '/content/xView/train_images'.
# Moved file '2195.tif' to '/content/xView/train_images'.
# Moved file '436.tif' to '/content/xView/train_images'.
# Moved file '978.tif' to '/content/xView/train_images'.
# Moved file '1066.tif' to '/content/xView/train_images'.
# Moved file '1102.tif' to '/content/xView/train_images'.
# Moved file '2563.tif' to '/content/xView/train_images'.
# Moved file '1916.tif' to '/content/xView/train_images'.
# Moved file '1833.tif' to '/content/xView/train_images'.
# Moved file '631.tif' to '/content/xView/train_images'.
# Moved file '1650.tif' to '/content/xView/train_images'.
# Moved file '1043.tif' to '/content/xView/train_images'.
# Moved file '1263.tif' to '/content/xView/train_images'.
# Moved file '1895.tif' to '/content/xView/train_images'.
# Moved file '2411.tif' to '/content/xView/train_images'.
# Moved file '908.tif' to '/content/xView/train_images'.
# Moved file '1835.tif' to '/content/xView/train_images'.
# Moved file '1935.tif' to '/content/xView/train_images'.
# Moved file '1506.tif' to '/content/xView/train_images'.
# Moved file '929.tif' to '/content/xView/train_images'.
# Moved file '1115.tif' to '/content/xView/train_images'.
# Moved file '1925.tif' to '/content/xView/train_images'.
# Moved file '2442.tif' to '/content/xView/train_images'.
# Moved file '327.tif' to '/content/xView/train_images'.
# Moved file '1946.tif' to '/content/xView/train_images'.
# Moved file '2402.tif' to '/content/xView/train_images'.
# Moved file '530.tif' to '/content/xView/train_images'.
# Moved file '205.tif' to '/content/xView/train_images'.
# Moved file '9.tif' to '/content/xView/train_images'.
# Moved file '945.tif' to '/content/xView/train_images'.
# Moved file '420.tif' to '/content/xView/train_images'.
# Moved file '1627.tif' to '/content/xView/train_images'.
# Moved file '1693.tif' to '/content/xView/train_images'.
# Moved file '1520.tif' to '/content/xView/train_images'.
# Moved file '121.tif' to '/content/xView/train_images'.
# Moved file '1282.tif' to '/content/xView/train_images'.
# Moved file '354.tif' to '/content/xView/train_images'.
# Moved file '1235.tif' to '/content/xView/train_images'.
# Moved file '543.tif' to '/content/xView/train_images'.
# Moved file '1605.tif' to '/content/xView/train_images'.
# Moved file '2102.tif' to '/content/xView/train_images'.
# Moved file '143.tif' to '/content/xView/train_images'.
# Moved file '1599.tif' to '/content/xView/train_images'.
# Moved file '1836.tif' to '/content/xView/train_images'.
# All files moved successfully.

# %% [markdown]
# ### Check Tree Structure

# %%
# %cd ~/../content/
# Check the directory structure of the data

# !tree xView
# Out:
# /content
# /bin/bash: tree: command not found

# %% [markdown]
# ### Visualise image and label

# %%
img = mmcv.imread('/content/xView/train_images/1038.tif')
print("img shape: {}".format(img.shape))
plt.figure(figsize=(15, 10))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()
# Out:
# img shape: (3215, 3195, 3)

# %% [markdown]
# ### Convert to COCO

# %%
xview_to_coco(XVIEW_TRAIN_IMAGES_DIR, XVIEW_TRAIN_GEOJSON_PATH, XVIEW_OUTPUT_DIR)
# Out:
# Parsing xView data: 100%|██████████| 601937/601937 [00:02<00:00, 267057.43it/s]
# Converting xView data into COCO format: 100%|██████████| 846/846 [01:05<00:00, 12.93it/s]

# %% [markdown]
# ### NOT USED: xView COCO Slice

# %%
"""%mkdir /content/xView_slice_train/
# %mkdir /content/xView_slice_val/"""

# %%
"""# train
slice_xview(image_dir=XVIEW_IMAGES_DIR, dataset_json_path=XVIEW_TRAIN_GEOJSON_PATH, output_dir=XVIEW_SLICE_TRAIN_OUTPUT_DIR)

# val
slice_xview(image_dir=XVIEW_IMAGES_DIR, dataset_json_path=XVIEW_VAL_GEOJSON_PATH, output_dir=XVIEW_SLICE_VAL_OUTPUT_DIR)"""

# %% [markdown]
# ## MMDet RetinaNet ResNet Backbone

# %% [markdown]
# ### ResNet + RetinaNet Config file

# %%
# %cat /content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/retinanet_resnet_config.py
# Out:
# # the new config inherits the base configs to highlight the necessary modification
# _base_ = '/content/mmdetection/configs/retinanet/retinanet_r101_fpn_1x_coco.py'
#
# fp16 = dict(loss_scale=512.)
#
# # set grad_norm for stability during mixed-precision training
# optimizer_config = dict(
#     _delete_=True, grad_clip=dict(max_norm=35, norm_type=2))
#
# # optimizer
# optim_wrapper = dict(optimizer=dict(type='SGD', lr=0.01, momentum=0.9))
#
# # 1. dataset settings
# dataset_type = 'CocoDataset'
#
# classes = ('Fixed-wing Aircraft',
# 'Small Aircraft',
# 'Cargo Plane',
# 'Helicopter',
# 'Passenger Vehicle',
# 'Small Car',
# 'Bus',
# 'Pickup Truck',
# 'Utility Truck',
# 'Truck',
# 'Cargo Truck',
# 'Truck w/Box',
# 'Truck Tractor',
# 'Trailer',
# 'Truck w/Flatbed',
# 'Truck w/Liquid',
# 'Crane Truck',
# 'Railway Vehicle',
# 'Passenger Car',
# 'Cargo Car',
# 'Flat Car',
# 'Tank car',
# 'Locomotive',
# 'Maritime Vessel',
# 'Motorboat',
# 'Sailboat',
# 'Tugboat',
# 'Barge',
# 'Fishing Vessel',
# 'Ferry',
# 'Yacht',
# 'Container Ship',
# 'Oil Tanker',
# 'Engineering Vehicle',
# 'Tower crane',
# 'Container Crane',
# 'Reach Stacker',
# 'Straddle Carrier',
# 'Mobile Crane',
# 'Dump Truck',
# 'Haul Truck',
# 'Scraper/Tractor',
# 'Front loader/Bulldozer',
# 'Excavator',
# 'Cement Mixer',
# 'Ground Grader',
# 'Hut/Tent',
# 'Shed',
# 'Building',
# 'Aircraft Hangar',
# 'Damaged Building',
# 'Facility',
# 'Construction Site',
# 'Vehicle Lot',
# 'Helipad',
# 'Storage Tank',
# 'Shipping container lot',
# 'Shipping Container',
# 'Pylon',
# 'Tower'
# )
#
# data_root='/content/xView/'
#
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True), # xView img shape
#     dict(type='RandomCrop', crop_size=(512,512)),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
#
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     dataset=dict(
#         type=dataset_type,
#         # explicitly add your class names to the field `metainfo`
#         metainfo=dict(classes=classes),
#         data_root=data_root,
#         ann_file='train.json',
#         data_prefix=dict(img='train_images/'),
#         pipeline=train_pipeline
#         )
#     )
#
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     dataset=dict(
#         type=dataset_type,
#         test_mode=True,
#         # explicitly add your class names to the field `metainfo`
#         metainfo=dict(classes=classes),
#         data_root=data_root,
#         ann_file='val.json',
#         data_prefix=dict(img='train_images/')
#         )
#     )
#
# test_dataloader = val_dataloader
#
# # Modify metric related settings
# val_evaluator = dict(ann_file=data_root + 'val.json')
# test_evaluator = val_evaluator
#
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=5),
#     visualization=dict(type='DetVisualizationHook', draw=True)
#     )
#
# vis_backends = [dict(type='LocalVisBackend'),
#             dict(type='WandbVisBackend')]
#
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=vis_backends,
#     name='visualizer'
#     )
#
#
# model = dict(
#     bbox_head=dict(
#         num_classes=len(classes),
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             octave_base_scale=4,
#             scales_per_octave=3,
#             ratios=[0.5, 1.0, 2.0],
#             strides=[8, 16, 32, 64, 128])
#         ),
#     train_cfg=dict(
#         assigner=dict(
#             gpu_assign_thr=1
#             )
#         ),
#     backbone=dict(
#         with_cp=True)
#     )
#
# evaluation = dict(interval=1, metric='mAP')
#
# workflow = [('train', 1), ('val', 1)]
#
# # train, val, test loop config
# #train_cfg = dict(max_epochs=10, val_interval=1)
# #val_cfg = dict(type='ValLoop') # The validation loop type
# #test_cfg = dict(type='TestLoop') # The testing loop type
#
# #log_level = 'INFO'
#
# # We can use the pre-trained model to obtain higher performance
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/retinanet/retinanet_r101_fpn_mstrain_3x_coco/retinanet_r101_fpn_mstrain_3x_coco_20210720_214650-7ee888e0.pth'

# %% [markdown]
# ### Swin + RetinaNet Config file

# %%
# %cat /content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/retinanet_swin_config.py
# Out:
# # the new config inherits the base configs to highlight the necessary modification
# _base_ = [
#     '/content/mmdetection/configs/_base_/models/retinanet_r50_fpn.py',
#     '/content/mmdetection/configs/_base_/datasets/coco_detection.py',
#     '/content/mmdetection/configs/_base_/schedules/schedule_1x.py', '/content/mmdetection/configs/_base_/default_runtime.py'
#     ]
#
# pretrained = 'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth'  # noqa
#
# classes = ('Fixed-wing Aircraft',
# 'Small Aircraft',
# 'Cargo Plane',
# 'Helicopter',
# 'Passenger Vehicle',
# 'Small Car',
# 'Bus',
# 'Pickup Truck',
# 'Utility Truck',
# 'Truck',
# 'Cargo Truck',
# 'Truck w/Box',
# 'Truck Tractor',
# 'Trailer',
# 'Truck w/Flatbed',
# 'Truck w/Liquid',
# 'Crane Truck',
# 'Railway Vehicle',
# 'Passenger Car',
# 'Cargo Car',
# 'Flat Car',
# 'Tank car',
# 'Locomotive',
# 'Maritime Vessel',
# 'Motorboat',
# 'Sailboat',
# 'Tugboat',
# 'Barge',
# 'Fishing Vessel',
# 'Ferry',
# 'Yacht',
# 'Container Ship',
# 'Oil Tanker',
# 'Engineering Vehicle',
# 'Tower crane',
# 'Container Crane',
# 'Reach Stacker',
# 'Straddle Carrier',
# 'Mobile Crane',
# 'Dump Truck',
# 'Haul Truck',
# 'Scraper/Tractor',
# 'Front loader/Bulldozer',
# 'Excavator',
# 'Cement Mixer',
# 'Ground Grader',
# 'Hut/Tent',
# 'Shed',
# 'Building',
# 'Aircraft Hangar',
# 'Damaged Building',
# 'Facility',
# 'Construction Site',
# 'Vehicle Lot',
# 'Helipad',
# 'Storage Tank',
# 'Shipping container lot',
# 'Shipping Container',
# 'Pylon',
# 'Tower'
# )
#
# model = dict(
#     backbone=dict(
#         _delete_=True,
#         type='SwinTransformer',
#         embed_dims=96,
#         depths=[2, 2, 6, 2],
#         num_heads=[3, 6, 12, 24],
#         window_size=7,
#         mlp_ratio=4,
#         qkv_bias=True,
#         qk_scale=None,
#         drop_rate=0.,
#         attn_drop_rate=0.,
#         drop_path_rate=0.2,
#         patch_norm=True,
#         out_indices=(1, 2, 3),
#         # Please only add indices that would be used
#         # in FPN, otherwise some parameter will not be used
#         with_cp=True,
#         convert_weights=True,
#         init_cfg=dict(type='Pretrained', checkpoint=pretrained)),
#     neck=dict(in_channels=[192, 384, 768], start_level=0, num_outs=5),
#     bbox_head=dict(
#         num_classes=len(classes),
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             octave_base_scale=4,
#             scales_per_octave=3,
#             ratios=[0.5, 1.0, 2],
#             strides=[8, 16, 32, 64, 128]
#             )
#         ),
#     train_cfg=dict(
#         assigner=dict(
#         gpu_assign_thr=1
#             )
#         )
#     )
#
# # optimizer
# #optimizer=dict(type='AdamW')
# #optimizer=dict(type='AdamW', lr=0.0003, weight_decay=0.0001)
# #optim_wrapper = dict(optimizer=dict(type='Adam'))
# optim_wrapper = dict(optimizer=dict(type='SGD', lr=0.003))
#
#
# # 1. dataset settings
# dataset_type = 'CocoDataset'
#
# data_root='/content/xView/'
#
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True), # xView img shape
#     dict(type='RandomCrop', crop_size=(512,512)),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
#
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     dataset=dict(
#         type=dataset_type,
#         # explicitly add your class names to the field `metainfo`
#         metainfo=dict(classes=classes),
#         data_root=data_root,
#         ann_file='train.json',
#         data_prefix=dict(img='train_images/'),
#         pipeline=train_pipeline
#         )
#     )
#
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     dataset=dict(
#         type=dataset_type,
#         test_mode=True,
#         # explicitly add your class names to the field `metainfo`
#         metainfo=dict(classes=classes),
#         data_root=data_root,
#         ann_file='val.json',
#         data_prefix=dict(img='train_images/')
#         )
#     )
#
# test_dataloader = val_dataloader
#
# # Modify metric related settings
# val_evaluator = dict(
#     ann_file=data_root+'train.json',
#     type='CocoMetric',
#     metric=['bbox']
#     )
#
# evaluation = dict(interval=1, metric='mAP')
#
# #test_evaluator = val_evaluator
#
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=5),
#     visualization=dict(type='DetVisualizationHook', draw=True)
#     )
#
# vis_backends = [dict(type='LocalVisBackend'),
#             dict(type='WandbVisBackend')]
#
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=vis_backends,
#     name='visualizer'
#     )
#
# workflow = [('train', 1), ('val', 1)]
#
# # train, val, test loop config
# #train_cfg = dict(max_epochs=10, val_interval=1)
# #val_cfg = dict(type='ValLoop') # The validation loop type
# #test_cfg = dict(type='TestLoop') # The testing loop type
#
# #log_level = 'INFO'

# %% [markdown]
# ### Train

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
#  **FIXED: System runs out of memory during training.**
#
# Randomly cropped images reduces anchor generations used and other tricks from MMdet doc FAQ's
#
# If problem returns, edit anchor generator in bbox_head

# %% [markdown]
# **FIXED: validation epoch not working as can't find correct val images (looking for images in train set)**
#
# All images moved to /content/xView/train_images and val.json references difference images in that folder seperately to train.json

# %%
# !python /content/mmdetection/tools/train.py /content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/retinanet_swin_config.py
# Out:
# 04/15 11:51:52 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1516256803
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.7.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/15 11:51:54 - mmengine - INFO - Config:
# model = dict(
#     type='RetinaNet',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='SwinTransformer',
#         embed_dims=96,
#         depths=[2, 2, 6, 2],
#         num_heads=[3, 6, 12, 24],
#         window_size=7,
#         mlp_ratio=4,
#         qkv_bias=True,
#         qk_scale=None,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.2,
#         patch_norm=True,
#         out_indices=(1, 2, 3),
#         with_cp=True,
#         convert_weights=True,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth'
#         )),
#     neck=dict(
#         type='FPN',
#         in_channels=[192, 384, 768],
#         out_channels=256,
#         start_level=0,
#         add_extra_convs='on_input',
#         num_outs=5),
#     bbox_head=dict(
#         type='RetinaHead',
#         num_classes=60,
#         in_channels=256,
#         stacked_convs=4,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             octave_base_scale=4,
#             scales_per_octave=3,
#             ratios=[0.5, 1.0, 2],
#             strides=[8, 16, 32, 64, 128]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='FocalLoss',
#             use_sigmoid=True,
#             gamma=2.0,
#             alpha=0.25,
#             loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     train_cfg=dict(
#         assigner=dict(
#             type='MaxIoUAssigner',
#             pos_iou_thr=0.5,
#             neg_iou_thr=0.4,
#             min_pos_iou=0,
#             ignore_iof_thr=-1,
#             gpu_assign_thr=1),
#         sampler=dict(type='PseudoSampler'),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=1000,
#         min_bbox_size=0,
#         score_thr=0.05,
#         nms=dict(type='nms', iou_threshold=0.5),
#         max_per_img=100))
# dataset_type = 'CocoDataset'
# data_root = '/content/xView/'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='RandomCrop', crop_size=(512, 512)),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/content/xView/',
#         ann_file='train.json',
#         data_prefix=dict(img='train_images/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='RandomCrop', crop_size=(512, 512)),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('Fixed-wing Aircraft', 'Small Aircraft', 'Cargo Plane',
#                      'Helicopter', 'Passenger Vehicle', 'Small Car', 'Bus',
#                      'Pickup Truck', 'Utility Truck', 'Truck', 'Cargo Truck',
#                      'Truck w/Box', 'Truck Tractor', 'Trailer',
#                      'Truck w/Flatbed', 'Truck w/Liquid', 'Crane Truck',
#                      'Railway Vehicle', 'Passenger Car', 'Cargo Car',
#                      'Flat Car', 'Tank car', 'Locomotive', 'Maritime Vessel',
#                      'Motorboat', 'Sailboat', 'Tugboat', 'Barge',
#                      'Fishing Vessel', 'Ferry', 'Yacht', 'Container Ship',
#                      'Oil Tanker', 'Engineering Vehicle', 'Tower crane',
#                      'Container Crane', 'Reach Stacker', 'Straddle Carrier',
#                      'Mobile Crane', 'Dump Truck', 'Haul Truck',
#                      'Scraper/Tractor', 'Front loader/Bulldozer', 'Excavator',
#                      'Cement Mixer', 'Ground Grader', 'Hut/Tent', 'Shed',
#                      'Building', 'Aircraft Hangar', 'Damaged Building',
#                      'Facility', 'Construction Site', 'Vehicle Lot', 'Helipad',
#                      'Storage Tank', 'Shipping container lot',
#                      'Shipping Container', 'Pylon', 'Tower'))))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/content/xView/',
#         ann_file='val.json',
#         data_prefix=dict(img='train_images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('Fixed-wing Aircraft', 'Small Aircraft', 'Cargo Plane',
#                      'Helicopter', 'Passenger Vehicle', 'Small Car', 'Bus',
#                      'Pickup Truck', 'Utility Truck', 'Truck', 'Cargo Truck',
#                      'Truck w/Box', 'Truck Tractor', 'Trailer',
#                      'Truck w/Flatbed', 'Truck w/Liquid', 'Crane Truck',
#                      'Railway Vehicle', 'Passenger Car', 'Cargo Car',
#                      'Flat Car', 'Tank car', 'Locomotive', 'Maritime Vessel',
#                      'Motorboat', 'Sailboat', 'Tugboat', 'Barge',
#                      'Fishing Vessel', 'Ferry', 'Yacht', 'Container Ship',
#                      'Oil Tanker', 'Engineering Vehicle', 'Tower crane',
#                      'Container Crane', 'Reach Stacker', 'Straddle Carrier',
#                      'Mobile Crane', 'Dump Truck', 'Haul Truck',
#                      'Scraper/Tractor', 'Front loader/Bulldozer', 'Excavator',
#                      'Cement Mixer', 'Ground Grader', 'Hut/Tent', 'Shed',
#                      'Building', 'Aircraft Hangar', 'Damaged Building',
#                      'Facility', 'Construction Site', 'Vehicle Lot', 'Helipad',
#                      'Storage Tank', 'Shipping container lot',
#                      'Shipping Container', 'Pylon', 'Tower'))))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/content/xView/',
#         ann_file='val.json',
#         data_prefix=dict(img='train_images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None,
#         metainfo=dict(
#             classes=('Fixed-wing Aircraft', 'Small Aircraft', 'Cargo Plane',
#                      'Helicopter', 'Passenger Vehicle', 'Small Car', 'Bus',
#                      'Pickup Truck', 'Utility Truck', 'Truck', 'Cargo Truck',
#                      'Truck w/Box', 'Truck Tractor', 'Trailer',
#                      'Truck w/Flatbed', 'Truck w/Liquid', 'Crane Truck',
#                      'Railway Vehicle', 'Passenger Car', 'Cargo Car',
#                      'Flat Car', 'Tank car', 'Locomotive', 'Maritime Vessel',
#                      'Motorboat', 'Sailboat', 'Tugboat', 'Barge',
#                      'Fishing Vessel', 'Ferry', 'Yacht', 'Container Ship',
#                      'Oil Tanker', 'Engineering Vehicle', 'Tower crane',
#                      'Container Crane', 'Reach Stacker', 'Straddle Carrier',
#                      'Mobile Crane', 'Dump Truck', 'Haul Truck',
#                      'Scraper/Tractor', 'Front loader/Bulldozer', 'Excavator',
#                      'Cement Mixer', 'Ground Grader', 'Hut/Tent', 'Shed',
#                      'Building', 'Aircraft Hangar', 'Damaged Building',
#                      'Facility', 'Construction Site', 'Vehicle Lot', 'Helipad',
#                      'Storage Tank', 'Shipping container lot',
#                      'Shipping Container', 'Pylon', 'Tower'))))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file='/content/xView/train.json',
#     metric=['bbox'],
#     format_only=False,
#     backend_args=None)
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data/coco/annotations/instances_val2017.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None)
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=12, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.003, momentum=0.9, weight_decay=0.0001))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=5),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook', draw=True))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend'), dict(type='WandbVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend'),
#                   dict(type='WandbVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# pretrained = 'https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth'
# classes = ('Fixed-wing Aircraft', 'Small Aircraft', 'Cargo Plane',
#            'Helicopter', 'Passenger Vehicle', 'Small Car', 'Bus',
#            'Pickup Truck', 'Utility Truck', 'Truck', 'Cargo Truck',
#            'Truck w/Box', 'Truck Tractor', 'Trailer', 'Truck w/Flatbed',
#            'Truck w/Liquid', 'Crane Truck', 'Railway Vehicle', 'Passenger Car',
#            'Cargo Car', 'Flat Car', 'Tank car', 'Locomotive',
#            'Maritime Vessel', 'Motorboat', 'Sailboat', 'Tugboat', 'Barge',
#            'Fishing Vessel', 'Ferry', 'Yacht', 'Container Ship', 'Oil Tanker',
#            'Engineering Vehicle', 'Tower crane', 'Container Crane',
#            'Reach Stacker', 'Straddle Carrier', 'Mobile Crane', 'Dump Truck',
#            'Haul Truck', 'Scraper/Tractor', 'Front loader/Bulldozer',
#            'Excavator', 'Cement Mixer', 'Ground Grader', 'Hut/Tent', 'Shed',
#            'Building', 'Aircraft Hangar', 'Damaged Building', 'Facility',
#            'Construction Site', 'Vehicle Lot', 'Helipad', 'Storage Tank',
#            'Shipping container lot', 'Shipping Container', 'Pylon', 'Tower')
# evaluation = dict(interval=1, metric='mAP')
# workflow = [('train', 1), ('val', 1)]
# launcher = 'none'
# work_dir = './work_dirs/retinanet_swin_config'
#
# wandb: Currently logged in as: horsada. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.14.2
# wandb: Run data is saved locally in /content/work_dirs/retinanet_swin_config/20230415_115151/vis_data/wandb/run-20230415_115201-tdcka5xa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lyric-resonance-65
# wandb: ⭐️ View project at https://wandb.ai/horsada/uncategorized
# wandb: 🚀 View run at https://wandb.ai/horsada/uncategorized/runs/tdcka5xa
# 04/15 11:52:09 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/15 11:52:09 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=3.20s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.75s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=2.95s)
# creating index...
# index created!
# 04/15 11:52:26 - mmengine - INFO - Loads checkpoint by http backend from path: https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth
# 04/15 11:52:27 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
#
# 04/15 11:57:47 - mmengine - INFO - Epoch(train)  [1][590/634]  lr: 3.0000e-03  eta: 1:03:26  time: 0.5531  data_time: 0.0197  memory: 864  loss: 2.0011  loss_cls: 1.2099  loss_bbox: 0.7912
# 04/15 11:57:50 - mmengine - INFO - Epoch(train)  [1][595/634]  lr: 3.0000e-03  eta: 1:03:29  time: 0.5707  data_time: 0.0196  memory: 862  loss: 1.9907  loss_cls: 1.2022  loss_bbox: 0.7885
# 04/15 11:57:52 - mmengine - INFO - Epoch(train)  [1][600/634]  lr: 3.0000e-03  eta: 1:03:24  time: 0.5753  data_time: 0.0197  memory: 862  loss: 2.0025  loss_cls: 1.1825  loss_bbox: 0.8200
# 04/15 11:57:55 - mmengine - INFO - Epoch(train)  [1][605/634]  lr: 3.0000e-03  eta: 1:03:20  time: 0.5566  data_time: 0.0051  memory: 862  loss: 2.0495  loss_cls: 1.1917  loss_bbox: 0.8578
# 04/15 11:57:58 - mmengine - INFO - Epoch(train)  [1][610/634]  lr: 3.0000e-03  eta: 1:03:22  time: 0.5767  data_time: 0.0051  memory: 864  loss: 2.0784  loss_cls: 1.2138  loss_bbox: 0.8646
# 04/15 11:58:00 - mmengine - INFO - Epoch(train)  [1][615/634]  lr: 3.0000e-03  eta: 1:03:13  time: 0.5606  data_time: 0.0053  memory: 862  loss: 2.0761  loss_cls: 1.2103  loss_bbox: 0.8657
# 04/15 11:58:03 - mmengine - INFO - Epoch(train)  [1][620/634]  lr: 3.0000e-03  eta: 1:03:11  time: 0.5448  data_time: 0.0053  memory: 862  loss: 2.1780  loss_cls: 1.3217  loss_bbox: 0.8563
# 04/15 11:58:06 - mmengine - INFO - Epoch(train)  [1][625/634]  lr: 3.0000e-03  eta: 1:03:06  time: 0.5409  data_time: 0.0054  memory: 862  loss: 2.1419  loss_cls: 1.2875  loss_bbox: 0.8544
# 04/15 11:58:09 - mmengine - INFO - Epoch(train)  [1][630/634]  lr: 3.0000e-03  eta: 1:03:06  time: 0.5412  data_time: 0.0054  memory: 864  loss: 2.1062  loss_cls: 1.2880  loss_bbox: 0.8181
# 04/15 11:58:10 - mmengine - INFO - Exp name: retinanet_swin_config_20230415_115151
# 04/15 11:58:10 - mmengine - INFO - Saving checkpoint at 1 epochs
# 04/15 11:58:16 - mmengine - INFO - Epoch(val)  [1][  5/212]    eta: 0:01:26  time: 0.4163  data_time: 0.2588  memory: 862
# 04/15 11:58:16 - mmengine - INFO - Epoch(val)  [1][ 10/212]    eta: 0:00:58  time: 0.2883  data_time: 0.1551  memory: 547
# 04/15 11:58:18 - mmengine - INFO - Epoch(val)  [1][ 15/212]    eta: 0:00:52  time: 0.2662  data_time: 0.1347  memory: 636
# /usr/local/lib/python3.9/dist-packages/mmengine/visualization/visualizer.py:741: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/mmengine/visualization/visualizer.py:812: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages
# 04/15 12:18:17 - mmengine - INFO - Epoch(train)  [4][575/634]  lr: 3.0000e-03  eta: 0:45:24  time: 0.5315  data_time: 0.0190  memory: 862  loss: 1.7540  loss_cls: 1.0286  loss_bbox: 0.7254
# 04/15 12:18:19 - mmengine - INFO - Epoch(train)  [4][580/634]  lr: 3.0000e-03  eta: 0:45:20  time: 0.5141  data_time: 0.0185  memory: 864  loss: 1.7414  loss_cls: 1.0223  loss_bbox: 0.7191
# 04/15 12:18:21 - mmengine - INFO - Epoch(train)  [4][585/634]  lr: 3.0000e-03  eta: 0:45:16  time: 0.5001  data_time: 0.0185  memory: 862  loss: 1.7350  loss_cls: 1.0283  loss_bbox: 0.7067
# 04/15 12:18:23 - mmengine - INFO - Epoch(train)  [4][590/634]  lr: 3.0000e-03  eta: 0:45:11  time: 0.4590  data_time: 0.0047  memory: 862  loss: 1.8126  loss_cls: 1.1022  loss_bbox: 0.7105
# 04/15 12:18:25 - mmengine - INFO - Epoch(train)  [4][595/634]  lr: 3.0000e-03  eta: 0:45:08  time: 0.4558  data_time: 0.0047  memory: 862  loss: 1.8518  loss_cls: 1.1506  loss_bbox: 0.7012
# 04/15 12:18:29 - mmengine - INFO - Epoch(train)  [4][600/634]  lr: 3.0000e-03  eta: 0:45:07  time: 0.4843  data_time: 0.0048  memory: 865  loss: 1.8610  loss_cls: 1.1672  loss_bbox: 0.6939
# 04/15 12:18:32 - mmengine - INFO - Epoch(train)  [4][605/634]  lr: 3.0000e-03  eta: 0:45:05  time: 0.4972  data_time: 0.0050  memory: 862  loss: 1.8530  loss_cls: 1.1539  loss_bbox: 0.6991
# 04/15 12:18:34 - mmengine - INFO - Epoch(train)  [4][610/634]  lr: 3.0000e-03  eta: 0:45:01  time: 0.4988  data_time: 0.0050  memory: 864  loss: 1.8406  loss_cls: 1.1454  loss_bbox: 0.6953
# 04/15 12:18:37 - mmengine - INFO - Epoch(train)  [4][615/634]  lr: 3.0000e-03  eta: 0:44:59  time: 0.5056  data_time: 0.0051  memory: 862  loss: 1.8383  loss_cls: 1.1438  loss_bbox: 0.6945
# Traceback (most recent call last):
#   File "/content/mmdetection/tools/train.py", line 133, in <module>
#     main()
#   File "/content/mmdetection/tools/train.py", line 129, in main
#     runner.train()
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/runner.py", line 1706, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/loops.py", line 96, in run
#     self.run_epoch()
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/loops.py", line 112, in run_epoch
#     self.run_iter(idx, data_batch)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/loops.py", line 131, in run_iter
#     self.runner.call_hook(
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/runner.py", line 1768, in call_hook
#     getattr(hook, fn_name)(self, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/hooks/runtime_info_hook.py", line 120, in after_train_iter
#     runner.message_hub.update_scalar(f'train/{key}', value)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/logging/message_hub.py", line 139, in update_scalar
#     checked_value = self._get_valid_value(value)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/logging/message_hub.py", line 338, in _get_valid_value
#     value = value.item()
# KeyboardInterrupt
# wandb: Waiting for W&B process to finish... (failed 255). Press Control-C to abort syncing.
# wandb:
# wandb: Run history:
# wandb: data_time ▆▁▂▁▁▁▁▁▁▆▄▁▅▁▁▄▁▆▁▁▃▁▁▁▁▁▁▁▇▁▂█▁▁▁▁▁▁▁▁
# wandb:     epoch ▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▆▆▆▆▆▆▆▆▆▆██████████
# wandb:      loss █▅▄▆▄▄▄▅▃▅▇▃▆▃▄▅▃▄▄▃▄▃▃▃▃▅▄▄▄▂▃▃▂▃▃▁▂▁▃▂
# wandb: loss_bbox █▃▂▄▃▃▄▄▃▄▅▂▅▂▃▄▂▅▁▃▆▂▃▃▃▅▃▃▄▃▃▂▃▁▂▁▄▁▂▁
# wandb:  loss_cls █▇▅▇▅▆▄▅▄▆█▄▆▄▅▆▄▃▇▃▄▄▄▄▄▆▅▅▅▂▄▅▂▄▃▁▁▂▃▃
# wandb:        lr ▁▂▃▄▅▅▇▇████████████████████████████████
# wandb:    memory ▆▆▆▁▁▆▁▁▆▆▁▁▁▆▁▁▆▁▁▁▆▁▁▁▆█▁▁▁▁▁▆▁▁▁▁▁▁▁▁
# wandb:      time █▃▅▂▆▆▆▆▅▆▅▄▄▄▆▃▂▆▃▇▇▅▅▃▅▅▁▄▇▅▅▄▃▂▅▆▆█▄▄
# wandb:
# wandb: Run summary:
# wandb: data_time 0.00509
# wandb:     epoch 4
# wandb:      loss 1.83832
# wandb: loss_bbox 0.69452
# wandb:  loss_cls 1.1438
# wandb:        lr 0.003
# wandb:    memory 862
# wandb:      time 0.50561
# wandb:
# wandb: 🚀 View run lyric-resonance-65 at: https://wandb.ai/horsada/uncategorized/runs/tdcka5xa
# wandb: Synced 5 W&B file(s), 12 media file(s), 1501 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./work_dirs/retinanet_swin_config/20230415_115151/vis_data/wandb/run-20230415_115201-tdcka5xa/logs
# ^C

# %%
# !python /content/mmdetection/tools/analysis_tools/analyze_logs.py plot_curve /content/work_dirs/retinanet_swin_config/20230415_112440/vis_data/20230415_112440.json --keys loss_bbox --legend run1
# Out:
# plot curve of /content/work_dirs/retinanet_swin_config/20230415_112440/vis_data/20230415_112440.json, metric is loss_bbox
# Figure(640x480)

# %%
copy_file('/content/work_dirs/retinanet_swin_config/epoch_2.pth', '/content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV')
# Out:
# '/content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/epoch_2.pth'

# %% [markdown]
# ### Test

# %%
# !python /content/mmdetection/tools/test.py /content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/retinanet_config.py work_dirs/mask-rcnn_r50-caffe_fpn_ms-poly-1x_balloon/epoch_12.pth
# Out:
# Traceback (most recent call last):
#   File "/content/mmdetection/tools/test.py", line 149, in <module>
#     main()
#   File "/content/mmdetection/tools/test.py", line 74, in main
#     cfg = Config.fromfile(args.config)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/config/config.py", line 177, in fromfile
#     cfg_dict, cfg_text, env_variables = Config._file2dict(
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/config/config.py", line 449, in _file2dict
#     check_file_exist(filename)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/utils/path.py", line 23, in check_file_exist
#     raise FileNotFoundError(msg_tmpl.format(filename))
# FileNotFoundError: file "/content/drive/MyDrive/Spatial_Finance_Transport/MMDetCV/retinanet_config.py" does not exist
