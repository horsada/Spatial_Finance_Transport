# %% [markdown]
# # Data API

# %% [markdown]
# ## Imports

# %%
import urllib.request, json
import pandas as pd
import math
import pickle
import collections
from tqdm import tqdm
import geopandas
import datetime
import os
import numpy as np

# %% [markdown]
# ## Global Variables

# %%
START_DATE = '01062019'
END_DATE = '15062022'
MAX_LAT = 52.6
MAX_LONG = -0.32
MIN_LAT = 52.5
MIN_LONG = -0.33
QUALITY_THRESHOLD = 90
NORMALISE_DF = True

# %% [markdown]
# ## Initial Site Retrieval

# %%
# Download information about all UK sites
url_text = "https://webtris.highwaysengland.co.uk/api/v1/sites"
with urllib.request.urlopen(url_text) as url:
    data = json.loads(url.read().decode())
sites = data['sites']
sites
# Out:
# [{'Id': '1',
#   'Name': 'MIDAS site at M4/2295A2 priority 1 on link 105009001; GPS Ref: 502816;178156; Westbound',
#   'Description': 'M4/2295A2',
#   'Longitude': -0.520379557723297,
#   'Latitude': 51.4930115367112,
#   'Status': 'Inactive'},
#  {'Id': '2',
#   'Name': 'MIDAS site at A1M/2259B priority 1 on link 126046101; GPS Ref: 514029;294356; Southbound',
#   'Description': 'A1M/2259B',
#   'Longitude': -0.320275451712423,
#   'Latitude': 52.5351577963853,
#   'Status': 'Active'},
#  {'Id': '3',
#   'Name': 'MIDAS site at M5/7482B priority 1 on link 109001601; GPS Ref: 388120;253057; Northbound',
#   'Description': 'M5/7482B',
#   'Longitude': -2.17513825916014,
#   'Latitude': 52.1756517888158,
#   'Status': 'Active'},
#  {'Id': '4',
#   'Name': 'MIDAS site at M3/2173A priority 1 on link 103009101; GPS Ref: 442770;118058; Westbound',
#   'Description': 'M3/2173A',
#   'Longitude': -1.39237366736779,
#   'Latitude': 50.9603586282494,
#   'Status': 'Inactive'},
#  {'Id': '5',
#   'Name': 'MIDAS site at M25/5764B priority 1 on link 199056702; GPS Ref: 558308;188775; Anti-clockwise',
#   'Description': 'M25/5764B',
#   'Longitude': 0.283161593410359,
#   'Latitude': 51.5756168053165,
#   'Status': 'Active'},
#  {'Id': '6',
#   'Name': 'MIDAS site at M27/9273A priority 1 on link 103009302; GPS Ref: 448516;111110; Eastbound',
#   'Description': 'M27/9273A',
#   'Longitude': -1.31148605150526,
#   'Latitude': 50.8974291626176,
#   'Status': 'Inactive'},
#  {'Id': '7',
#   'Name': 'MIDAS site at A1M/9869K priority 1 on link 118013101; GPS Ref: 439428;465276; Northbound',
#   'Description': 'A1M/9869K',
#   'Longitude': -1.3988308536688,
#   'Latitude': 54.0819152173294,
#   'Status': 'Active'},
#  {'Id': '8',
#   'Name': 'MIDAS site at M25/4876A priority 1 on link 199132301; GPS Ref: 501669;171540; Clockwise',
#   'Description': 'M25/4876A',
#   'Longitude': -0.538795788123459,
#   'Latitude': 51.4337486439773,
#   'Status': 'Active'},
#  {'Id': '9',
#   'Name': 'MIDAS site at M60/9164M priority 1 on link 115021301; GPS Ref: 376508;396448; Anti-clockwise',
#   'Description': 'M60/9164M',
#   'Longitude': -2.35531413616728,
#   'Latitude': 53.4642620986179,
#   'Status': 'Inactive'},
#  {'Id': '10',
#   'Name': 'MIDAS site at M62/1686A priority 1 on link 125025001; GPS Ref: 393066;411906; Eastbound',
#   'Description': 'M62/1686A',
#   'Longitude': -2.10625799296015,
#   'Latitude': 53.6036856809869,
#   'Status': 'Inactive'},
#  {'Id': '11',
#   'Name': 'MIDAS site at M27/9387A priority 1 on link 103010501; GPS Ref: 458731;107342; Eastbound',
#   'Description': 'M27/9387A',
#   'Longitude': -1.16685001065065,
#   'Latitude': 50.8626033711616,
#   'Status': 'Inactive'},
#  {'Id': '12',
#   'Name': 'MIDAS site at M6/6760B priority 1 on link 110005801; GPS Ref: 374505;366313; Southbound',
#   'Description': 'M6/6760B',
#   'Longitude': -2.3830476202693,
#   'Latitude': 53.1933013796252,
#   'Status': 'Inactive'},
#  {'Id': '13',
#   'Name': 'MIDAS site at M62/2328B priority 1 on link 200017023; GPS Ref: 447418;423793; Westbound',
#   'Description': 'M62/2328B',
#   'Longitude': -1.28311525912878,
#   'Latitude': 53.7084340056232,
#   'Status': 'Active'},
#  {'Id': '14',
#   'Name': 'MIDAS site at A2/8392M priority 1 on link 200045660; GPS Ref: 565718;170406; Westbound',
#   'Description': 'A2/8392M',
#   'Longitude': 0.381381297925497,
#   'Latitude': 51.4084657748977,
#   'Status': 'Active'},
#  {'Id': '15',
#   'Name': 'MIDAS site at M6/6988B priority 1 on link 110003001; GPS Ref: 366171;385367; Southbound',
#   'Description': 'M6/6988B',
#   'Longitude': -2.50981634724319,
#   'Latitude': 53.3640990933116,
#   'Status': 'Active'},
#  {'Id': '16',
#   'Name': 'MIDAS site at M2/8460A priority 1 on link 200006989; GPS Ref: 571654;168165; Eastbound',
#   'Description': 'M2/8460A',
#   'Longitude': 0.465564013705534,
#   'Latitude': 51.3865701489037,
#   'Status': 'Inactive'},
#  {'Id': '17',
#   'Name': 'MIDAS site at M1/2413B priority 1 on link 200047604; GPS Ref: 509720;210823; Southbound',
#   'Description': 'M1/2413B',
#   'Longitude': -0.410736660991787,
#   'Latitude': 51.785325687602,
#   'Status': 'Active'},
#  {'Id': '18',
#   'Name': 'MIDAS site at M62/2099A priority 1 on link 116033901; GPS Ref: 425956;426222; Eastbound',
#   'Description': 'M62/2099A',
#   'Longitude': -1.60804240457756,
#   'Latitude': 53.7317663847111,
#   'Status': 'Active'},
#  {'Id': '19',
#   'Name': 'MIDAS site at M1/4890A priority 1 on link 116019602; GPS Ref: 430883;416335; Northbound',
#   'Description': 'M1/4890A',
#   'Longitude': -1.53434206597794,
#   'Latitude': 53.6426379215492,
#   'Status': 'Active'},
#  {'Id': '20',
#   'Name': 'MIDAS site at M3/2039B priority 1 on link 103045201; GPS Ref: 449606;129206; Eastbound',
#   'Description': 'M3/2039B',
#   'Longitude': -1.29352219641903,
#   'Latitude': 51.0600518502267,
#   'Status': 'Inactive'},
#  {'Id': '21',
#   'Name': 'MIDAS site at M1/4846A priority 1 on link 116017902; GPS Ref: 429734;412200; Northbound',
#   'Description': 'M1/4846A',
#   'Longitude': -1.55211479870336,
#   'Latitude': 53.605539135161,
#   'Status': 'Active'},
#  {'Id': '22',
#   'Name': 'MIDAS site at A14/1908A priority 1 on link 106048001; GPS Ref: 614456;241199; Eastbound',
#   'Description': 'A14/1908A',
#   'Longitude': 1.12471266263044,
#   'Latitude': 52.0277371244491,
#   'Status': 'Inactive'},
#  {'Id': '23',
#   'Name': 'MIDAS site at M3/2165M priority 1 on link 103008801; GPS Ref: 443385;118574; Westbound',
#   'Description': 'M3/2165M',
#   'Longitude': -1.38355582981386,
#   'Latitude': 50.9649525543084,
#   'Status': 'Inactive'},
#  {'Id': '24',
#   'Name': 'MIDAS site at M4/3479A priority 1 on link 102004601; GPS Ref: 396680;180193; Westbound',
#   'Description': 'M4/3479A',
#   'Longitude': -2.04923708882077,
#   'Latitude': 51.5206446979317,
#   'Status': 'Active'},
#  {'Id': '25',
#   'Name': 'MIDAS site at M25/5135B priority 1 on link 199004401; GPS Ref: 504275;197295; Anti-clockwise',
#   'Description': 'M25/5135B',
#   'Longitude': -0.493692290379283,
#   'Latitude': 51.6647732889977,
#   'Status': 'Active'},
#  {'Id': '26',
#   'Name': 'MIDAS site at M5/7138M priority 1 on link 112009302; GPS Ref: 399170;283740; Northbound',
#   'Description': 'M5/7138M',
#   'Longitude': -2.01363460823604,
#   'Latitude': 52.4516310473519,
#   'Status': 'Active'},
#  {'Id': '27',
#   'Name': 'MIDAS site at M1/2771A priority 1 on link 108020101; GPS Ref: 492031;239267; Northbound',
#   'Description': 'M1/2771A',
#   'Longitude': -0.659507454818221,
#   'Latitude': 52.0441804328676,
#   'Status': 'Inactive'},
#  {'Id': '28',
#   'Name': 'MIDAS site at M25/4490B priority 1 on link 103063502; GPS Ref: 527988;153760; Anti-clockwise',
#   'Description': 'M25/4490B',
#   'Longitude': -0.166749727292999,
#   'Latitude': 51.2686294730048,
#   'Status': 'Active'},
#  {'Id': '29',
#   'Name': 'MIDAS site at M6/5838B priority 1 on link 112004002; GPS Ref: 409165;290578; Southbound',
#   'Description': 'M6/5838B',
#   'Longitude': -1.86637710036871,
#   'Latitude': 52.5130297842231,
#   'Status': 'Active'},
#  {'Id': '30',
#   'Name': 'MIDAS site at M2/8528A priority 1 on link 200008383; GPS Ref: 575053;162382; Eastbound',
#   'Description': 'M2/8528A',
#   'Longitude': 0.511519341891257,
#   'Latitude': 51.3335833253599,
#   'Status': 'Active'},
#  {'Id': '31',
#   'Name': 'MIDAS site at M1/5163J priority 1 on link 116014701; GPS Ref: 441866;434633; Northbound',
#   'Description': 'M1/5163J',
#   'Longitude': -1.36575523550041,
#   'Latitude': 53.8063305024294,
#   'Status': 'Active'},
#  {'Id': '32',
#   'Name': 'MIDAS site at A1M/9468J priority 1 on link 108009601; GPS Ref: 523552;222388; Northbound',
#   'Description': 'A1M/9468J',
#   'Longitude': -0.206184200504546,
#   'Latitude': 51.8863748193294,
#   'Status': 'Active'},
#  {'Id': '33',
#   'Name': 'MIDAS site at M54/3154A priority 1 on link 200119800; GPS Ref: 391887;304493; Westbound',
#   'Description': 'M54/3154A',
#   'Longitude': -2.12131616559626,
#   'Latitude': 52.6381367762977,
#   'Status': 'Active'},
#  {'Id': '34',
#   'Name': 'MIDAS site at M56/8150A priority 1 on link 199090301; GPS Ref: 379633;384595; Westbound',
#   'Description': 'M56/8150A',
#   'Longitude': -2.30747451952892,
#   'Latitude': 53.3578532696194,
#   'Status': 'Active'},
#  {'Id': '35',
#   'Name': 'MIDAS site at M25/4101L priority 1 on link 104047102; GPS Ref: 554959;171081; Anti-clockwise',
#   'Description': 'M25/4101L',
#   'Longitude': 0.227108726206905,
#   'Latitude': 51.4175706095531,
#   'Status': 'Active'},
#  {'Id': '36',
#   'Name': 'MIDAS site at M1/3949L priority 1 on link 199017102; GPS Ref: 447138;336925; Southbound',
#   'Description': 'M1/3949L',
#   'Longitude': -1.30023354171539,
#   'Latitude': 52.9276908637872,
#   'Status': 'Active'},
#  {'Id': '37',
#   'Name': 'MIDAS site at M1/4623A priority 1 on link 116025801; GPS Ref: 438610;392803; Northbound',
#   'Description': 'M1/4623A',
#   'Longitude': -1.42036145363544,
#   'Latitude': 53.430624952497,
#   'Status': 'Inactive'},
#  {'Id': '38',
#   'Name': 'MIDAS site at M6/7412B priority 1 on link 117008202; GPS Ref: 355366;422271; Southbound',
#   'Description': 'M6/7412B',
#   'Longitude': -2.67744593093838,
#   'Latitude': 53.6949784923759,
#   'Status': 'Active'},
#  {'Id': '39',
#   'Name': 'MIDAS site at M25/4116A priority 1 on link 104026701; GPS Ref: 553973;169855; Clockwise',
#   'Description': 'M25/4116A',
#   'Longitude': 0.212408128616889,
#   'Latitude': 51.4068231439933,
#   'Status': 'Active'},
#  {'Id': '40',
#   'Name': 'MIDAS site at M25/5165M priority 1 on link 199004303; GPS Ref: 506995;198997; Anti-clockwise',
#   'Description': 'M25/5165M',
#   'Longitude': -0.453859069937714,
#   'Latitude': 51.6795610507823,
#   'Status': 'Active'},
#  {'Id': '41',
#   'Name': 'MIDAS site at M6/5962B priority 1 on link 112001801; GPS Ref: 399484;296775; Southbound',
#   'Description': 'M6/5962B',
#   'Longitude': -2.00903974156997,
#   'Latitude': 52.5688155752209,
#   'Status': 'Active'},
#  {'Id': '42',
#   'Name': 'MIDAS site at M1/2717J priority 1 on link 200113967; GPS Ref: 496935;236982; Northbound',
#   'Description': 'M1/2717J',
#   'Longitude': -0.588671777393511,
#   'Latitude': 52.0228078207321,
#   'Status': 'Active'},
#  {'Id': '43',
#   'Name': 'MIDAS site at M1/5157B priority 1 on link 200109149; GPS Ref: 441230;434599; Southbound',
#   'Description': 'M1/5157B',
#   'Longitude': -1.37541680718986,
#   'Latitude': 53.8060755334036,
#   'Status': 'Active'},
#  {'Id': '44',
#   'Name': 'MIDAS site at M1/2607J priority 1 on link 123018901; GPS Ref: 503099;228536; Northbound',
#   'Description': 'M1/2607J',
#   'Longitude': -0.501403815441771,
#   'Latitude': 51.9457870173472,
#   'Status': 'Active'},
#  {'Id': '45',
#   'Name': 'MIDAS Site at M20/6568B1 priority 1 on link 104030102; GPS Ref: 575546;158544; Westbound',
#   'Description': 'M20/6568B1',
#   'Longitude': 0.516700017015146,
#   'Latitude': 51.2989540853619,
#   'Status': 'Active'},
#  {'Id': '46',
#   'Name': 'MIDAS site at M25/4465A priority 3 on link 200116863; GPS Ref: 530403;153341; Clockwise',
#   'Description': 'M25/4465A',
#   'Longitude': -0.132304637948176,
#   'Latitude': 51.2643166814966,
#   'Status': 'Active'},
#  {'Id': '47',
#   'Name': 'MIDAS site at M621/1133A priority 1 on link 116021901; GPS Ref: 432159;429104; Eastbound',
#   'Description': 'M621/1133A',
#   'Longitude': -1.51372269250672,
#   'Latitude': 53.7573258693331,
#   'Status': 'Active'},
#  {'Id': '48',
#   'Name': 'MIDAS site at M42/6168A priority 1 on link 125027701; GPS Ref: 401176;273071; Northbound',
#   'Description': 'M42/6168A',
#   'Longitude': -1.98414915489083,
#   'Latitude': 52.3557157781717,
#   'Status': 'Active'},
#  {'Id': '49',
#   'Name': 'MIDAS site at M1/4085B priority 1 on link 107033101; GPS Ref: 450426;348844; Southbound',
#   'Description': 'M1/4085B',
#   'Longitude': -1.24947586930138,
#   'Latitude': 53.0345252401088,
#   'Status': 'Active'},
#  {'Id': '50',
#   'Name': 'MIDAS site at M5/9061A priority 1 on link 102033901; GPS Ref: 325860;125311; Southbound',
#   'Description': 'M5/9061A',
#   'Longitude': -3.05845535173993,
#   'Latitude': 51.0223653198881,
#   'Status': 'Inactive'},
#  {'Id': '51',
#   'Name': 'MIDAS site at M4/2718B priority 1 on link 123030901; GPS Ref: 466136;170752; Eastbound',
#   'Description': 'M4/2718B',
#   'Longitude': -1.05001089549856,
#   'Latitude': 51.4319210145245,
#   'Status': 'Inactive'},
#  {'Id': '52',
#   'Name': 'MIDAS site at M6/6199A priority 1 on link 111036901; GPS Ref: 392699;318595; Northbound',
#   'Description': 'M6/6199A',
#   'Longitude': -2.10963652517659,
#   'Latitude': 52.7649197939255,
#   'Status': 'Inactive'},
#  {'Id': '53',
#   'Name': 'MIDAS site at M1/3911A priority 3 on link 199017201; GPS Ref: 447157;333096; Northbound',
#   'Description': 'M1/3911A',
#   'Longitude': -1.30050439825804,
#   'Latitude': 52.8932716695729,
#   'Status': 'Inactive'},
#  {'Id': '54',
#   'Name': 'MIDAS site at M2/8818M priority 1 on link 104049502; GPS Ref: 601600;159621; Westbound',
#   'Description': 'M2/8818M',
#   'Longitude': 0.890554784159312,
#   'Latitude': 51.300008224268,
#   'Status': 'Active'},
#  {'Id': '55',
#   'Name': 'MIDAS site at M6/6827A priority 4 on link 123008901; GPS Ref: 373269;372810; Northbound',
#   'Description': 'M6/6827A',
#   'Longitude': -2.40209347687792,
#   'Latitude': 53.2516390727385,
#   'Status': 'Inactive'},
#  {'Id': '56',
#   'Name': 'MIDAS site at A2/8402A priority 1 on link 200045690; GPS Ref: 566623;170153; Eastbound',
#   'Description': 'A2/8402A',
#   'Longitude': 0.394262600443268,
#   'Latitude': 51.4059280094946,
#   'Status': 'Active'},
#  {'Id': '57',
#   'Name': 'MIDAS site at M25/4322B priority 1 on link 125019301; GPS Ref: 544057;154700; Anti-clockwise',
#   'Description': 'M25/4322B',
#   'Longitude': 0.063815575561992,
#   'Latitude': 51.2732442603408,
#   'Status': 'Inactive'},
#  {'Id': '58',
#   'Name': 'MIDAS site at M5/7242B priority 1 on link 199096302; GPS Ref: 396200;274670; Northbound',
#   'Description': 'M5/7242B',
#   'Longitude': -2.0572298399486,
#   'Latitude': 52.3700765563849,
#   'Status': 'Active'},
#  {'Id': '59',
#   'Name': 'MIDAS site at A1M/9922B priority 1 on link 118013201; GPS Ref: 438308;470312; Southbound',
#   'Description': 'A1M/9922B',
#   'Longitude': -1.41531351729951,
#   'Latitude': 54.1272574607441,
#   'Status': 'Active'},
#  {'Id': '60',
#   'Name': 'MIDAS site at M1/3702B priority 1 on link 126024001; GPS Ref: 448097;313165; Southbound',
#   'Description': 'M1/3702B',
#   'Longitude': -1.28945574211469,
#   'Latitude': 52.7140329405801,
#   'Status': 'Active'},
#  {'Id': '61',
#   'Name': 'MIDAS site at M4/3549A priority 1 on link 123001901; GPS Ref: 389782;179198; Westbound',
#   'Description': 'M4/3549A',
#   'Longitude': -2.14862738076441,
#   'Latitude': 51.511613746296,
#   'Status': 'Active'},
#  {'Id': '62',
#   'Name': 'MIDAS site at M1/3130A priority 8 on link 123016901(Non-monitoring MIDAS); GPS Ref: 464284;261243; Northbound',
#   'Description': 'M1/3130A',
#   'Longitude': -1.05986463779637,
#   'Latitude': 52.2456395620733,
#   'Status': 'Inactive'},
#  {'Id': '63',
#   'Name': 'MIDAS site at M4/3507A priority 1 on link 102004601; GPS Ref: 393995;179491; Westbound',
#   'Description': 'M4/3507A',
#   'Longitude': -2.08792352225887,
#   'Latitude': 51.514309957611,
#   'Status': 'Active'},
#  {'Id': '64',
#   'Name': 'MIDAS site at M62/1324A priority 1 on link 199086001; GPS Ref: 365923;393146; Eastbound',
#   'Description': 'M62/1324A',
#   'Longitude': -2.51438656199428,
#   'Latitude': 53.4340026856307,
#   'Status': 'Inactive'},
#  {'Id': '65',
#   'Name': 'MIDAS site at M11/6904A priority 1 on link 200130235; GPS Ref: 541607;261047; Northbound',
#   'Description': 'M11/6904A',
#   'Longitude': 0.07199789011987,
#   'Latitude': 52.2294340480105,
#   'Status': 'Active'},
#  {'Id': '66',
#   'Name': 'MIDAS site at M1/3563B priority 1 on link 107032803; GPS Ref: 454289;301774; Southbound',
#   'Description': 'M1/3563B',
#   'Longitude': -1.19967870958693,
#   'Latitude': 52.6110568267452,
#   'Status': 'Active'},
#  {'Id': '67',
#   'Name': 'MIDAS site at M1/3776A priority 4 on link 107031701; GPS Ref: 448618;320430; Northbound',
#   'Description': 'M1/3776A',
#   'Longitude': -1.28067137873216,
#   'Latitude': 52.7792908506016,
#   'Status': 'Active'},
#  {'Id': '68',
#   'Name': 'MIDAS Site at M20/6568A1 priority 1 on link 104029103; GPS Ref: 575522;158555; Eastbound',
#   'Description': 'M20/6568A1',
#   'Longitude': 0.516361527817416,
#   'Latitude': 51.2990602918532,
#   'Status': 'Active'},
#  {'Id': '69',
#   'Name': 'MIDAS site at M1/2623B priority 1 on link 200113964; GPS Ref: 502135;229759; Southbound',
#   'Description': 'M1/2623B',
#   'Longitude': -0.515061150712143,
#   'Latitude': 51.956956888434,
#   'Status': 'Active'},
#  {'Id': '70',
#   'Name': 'MIDAS site at M6/6998A priority 1 on link 110002601; GPS Ref: 366305;386441; Northbound',
#   'Description': 'M6/6998A',
#   'Longitude': -2.50791789128287,
#   'Latitude': 53.3737612466491,
#   'Status': 'Active'},
#  {'Id': '71',
#   'Name': 'MIDAS site at M1/2926A priority 3 on link 108019502; GPS Ref: 480229;249190; Northbound',
#   'Description': 'M1/2926A',
#   'Longitude': -0.829220735020941,
#   'Latitude': 52.135208267394,
#   'Status': 'Inactive'},
#  {'Id': '72',
#   'Name': 'MIDAS site at M4/3332L priority 1 on link 102001801; GPS Ref: 409934;183135; Eastbound',
#   'Description': 'M4/3332L',
#   'Longitude': -1.85812655515843,
#   'Latitude': 51.5470238397031,
#   'Status': 'Active'},
#  {'Id': '73',
#   'Name': 'MIDAS site at M25/5235K priority 1 on link 108024201; GPS Ref: 512430;203156; Clockwise',
#   'Description': 'M25/5235K',
#   'Longitude': -0.373941587890524,
#   'Latitude': 51.7158794591327,
#   'Status': 'Active'},
#  {'Id': '74',
#   'Name': 'MIDAS site at M1/4065B priority 1 on link 107033101; GPS Ref: 450821;346881; Southbound',
#   'Description': 'M1/4065B',
#   'Longitude': -1.24389459422563,
#   'Latitude': 53.0168438863603,
#   'Status': 'Active'},
#  {'Id': '75',
#   'Name': 'MIDAS site at M25/4447B priority 3 on link 199121901; GPS Ref: 532106;152830; Anti-clockwise',
#   'Description': 'M25/4447B',
#   'Longitude': -0.108097854120412,
#   'Latitude': 51.2593320812814,
#   'Status': 'Active'},
#  {'Id': '76',
#   'Name': 'MIDAS site at M4/2502A priority 1 on link 105007301; GPS Ref: 485180;174964; Westbound',
#   'Description': 'M4/2502A',
#   'Longitude': -0.77511595906634,
#   'Latitude': 51.4672467236443,
#   'Status': 'Inactive'},
#  {'Id': '77',
#   'Name': 'MIDAS site at M1/4846L priority 1 on link 116009901; GPS Ref: 429776;412210; Southbound',
#   'Description': 'M1/4846L',
#   'Longitude': -1.55147913379074,
#   'Latitude': 53.6056266464746,
#   'Status': 'Active'},
#  {'Id': '78',
#   'Name': 'MIDAS site at A2/8420A priority 1 on link 200008841; GPS Ref: 568477;169674; Eastbound',
#   'Description': 'A2/8420A',
#   'Longitude': 0.420665735650981,
#   'Latitude': 51.401077667589,
#   'Status': 'Active'},
#  {'Id': '79',
#   'Name': 'MIDAS site at A1M/9470A priority 1 on link 108009401; GPS Ref: 523534;222509; Northbound',
#   'Description': 'A1M/9470A',
#   'Longitude': -0.206402323058378,
#   'Latitude': 51.8874661652699,
#   'Status': 'Active'},
#  {'Id': '80',
#   'Name': 'MIDAS site at M25/4409B priority 1 on link 123011501; GPS Ref: 535888;152808; Anti-clockwise',
#   'Description': 'M25/4409B',
#   'Longitude': -0.053937862271571,
#   'Latitude': 51.2582460746526,
#   'Status': 'Active'},
#  {'Id': '81',
#   'Name': 'MIDAS site at M6/7313B priority 1 on link 117007102; GPS Ref: 354533;412534; Southbound',
#   'Description': 'M6/7313B',
#   'Longitude': -2.68863437858823,
#   'Latitude': 53.6073952004655,
#   'Status': 'Active'},
#  {'Id': '82',
#   'Name': 'MIDAS site at M62/2324A priority 1 on link 200017490; GPS Ref: 447037;424070; Eastbound',
#   'Description': 'M62/2324A',
#   'Longitude': -1.28884504984965,
#   'Latitude': 53.7109578839438,
#   'Status': 'Active'},
#  {'Id': '83',
#   'Name': 'MIDAS site at M6/7096B priority 1 on link 117015301; GPS Ref: 361194;394001; Southbound',
#   'Description': 'M6/7096B',
#   'Longitude': -2.58566816043069,
#   'Latitude': 53.4413595557882,
#   'Status': 'Active'},
#  {'Id': '84',
#   'Name': 'MIDAS site at M40/9061K priority 1 on link 200034725; GPS Ref: 454748;227915; Northbound',
#   'Description': 'M40/9061K',
#   'Longitude': -1.20485835708065,
#   'Latitude': 51.947054713298,
#   'Status': 'Active'},
#  {'Id': '85',
#   'Name': 'MIDAS site at M56/8114J priority 1 on link 115007401; GPS Ref: 381672;387320; Westbound',
#   'Description': 'M56/8114J',
#   'Longitude': -2.27699892832543,
#   'Latitude': 53.3824218923632,
#   'Status': 'Active'},
#  {'Id': '86',
#   'Name': 'MIDAS site at M1/3966A priority 1 on link 123013701; GPS Ref: 448119;338259; Northbound',
#   'Description': 'M1/3966A',
#   'Longitude': -1.28544465160147,
#   'Latitude': 52.9395949413968,
#   'Status': 'Active'},
#  {'Id': '87',
#   'Name': 'MIDAS site at M1/4017B priority 1 on link 123013901; GPS Ref: 450476;342713; Southbound',
#   'Description': 'M1/4017B',
#   'Longitude': -1.24968594385032,
#   'Latitude': 52.9794139703691,
#   'Status': 'Active'},
#  {'Id': '88',
#   'Name': 'MIDAS site at A14/2060J priority 1 on link 199136301; GPS Ref: 627790;237894; Eastbound',
#   'Description': 'A14/2060J',
#   'Longitude': 1.31654142435839,
#   'Latitude': 51.9927623053437,
#   'Status': 'Active'},
#  {'Id': '89',
#   'Name': 'MIDAS site at M6/6772K priority 1 on link 110005302; GPS Ref: 374168;367304; Northbound',
#   'Description': 'M6/6772K',
#   'Longitude': -2.38817178440203,
#   'Latitude': 53.2021927089163,
#   'Status': 'Inactive'},
#  {'Id': '90',
#   'Name': 'MIDAS site at M4/3869B priority 1 on link 102019301; GPS Ref: 361726;183912; Eastbound',
#   'Description': 'M4/3869B',
#   'Longitude': -2.55341652947819,
#   'Latitude': 51.5527877134557,
#   'Status': 'Active'},
#  {'Id': '91',
#   'Name': 'MIDAS site at M40/8789A priority 1 on link 199011101; GPS Ref: 462610;204895; Northbound',
#   'Description': 'M40/8789A',
#   'Longitude': -1.09464653191839,
#   'Latitude': 51.7392774926581,
#   'Status': 'Active'},
#  {'Id': '92',
#   'Name': 'MIDAS site at M3/2161B priority 1 on link 103008401; GPS Ref: 443618;118920; Eastbound',
#   'Description': 'M3/2161B',
#   'Longitude': -1.38019665524034,
#   'Latitude': 50.9680462028602,
#   'Status': 'Inactive'},
#  {'Id': '93',
#   'Name': 'MIDAS site at A1M/9541A priority 1 on link 200013589; GPS Ref: 443428;435666; Northbound',
#   'Description': 'A1M/9541A',
#   'Longitude': -1.34189279281093,
#   'Latitude': 53.8154869806696,
#   'Status': 'Active'},
#  {'Id': '94',
#   'Name': 'MIDAS site at M25/4090K priority 1 on link 200109283; GPS Ref: 555661;171840; Clockwise',
#   'Description': 'M25/4090K',
#   'Longitude': 0.2375293155224,
#   'Latitude': 51.424197681772704,
#   'Status': 'Active'},
#  {'Id': '95',
#   'Name': 'MIDAS site at A1M/2228B priority 1 on link 199047701; GPS Ref: 515756;291813; Southbound',
#   'Description': 'A1M/2228B',
#   'Longitude': -0.295709619220688,
#   'Latitude': 52.5119428099963,
#   'Status': 'Active'},
#  {'Id': '96',
#   'Name': 'MIDAS site at A1M/9379B priority 1 on link 200014145; GPS Ref: 448072;421977; Southbound',
#   'Description': 'A1M/9379B',
#   'Longitude': -1.27348778862802,
#   'Latitude': 53.6920534408536,
#   'Status': 'Active'},
#  {'Id': '97',
#   'Name': 'MIDAS site at M25/4358A priority 1 on link 199121802; GPS Ref: 540570;153968; Clockwise',
#   'Description': 'M25/4358A',
#   'Longitude': 0.01357216902312,
#   'Latitude': 51.2675362903577,
#   'Status': 'Active'},
#  {'Id': '98',
#   'Name': 'MIDAS site at M4/3434A priority 1 on link 102004601; GPS Ref: 400706;182090; Westbound',
#   'Description': 'M4/3434A',
#   'Longitude': -1.99120709144118,
#   'Latitude': 51.537712146872,
#   'Status': 'Active'},
#  {'Id': '99',
#   'Name': 'MIDAS site at M1/2501A priority 1 on link 108023301; GPS Ref: 507983;219359; Northbound',
#   'Description': 'M1/2501A',
#   'Longitude': -0.433247673382439,
#   'Latitude': 51.8623826551344,
#   'Status': 'Active'},
#  {'Id': '100',
#   'Name': 'MIDAS site at M60/9462B priority 1 on link 115028601; GPS Ref: 392195;398032; Anti-clockwise',
#   'Description': 'M60/9462B',
#   'Longitude': -2.11907034674187,
#   'Latitude': 53.4789693723244,
#   'Status': 'Active'},
#  {'Id': '101',
#   'Name': 'MIDAS site at M5/8291A priority 1 on link 102020202; GPS Ref: 363164;185008; Southbound',
#   'Description': 'M5/8291A',
#   'Longitude': -2.53279203259531,
#   'Latitude': 51.5627381612544,
#   'Status': 'Active'},
#  {'Id': '102',
#   'Name': 'MIDAS site at A1M/9897A priority 1 on link 118013501; GPS Ref: 438364;467838; Northbound',
#   'Description': 'A1M/9897A',
#   'Longitude': -1.41476954180917,
#   'Latitude': 54.1050197824865,
#   'Status': 'Active'},
#  {'Id': '103',
#   'Name': 'MIDAS site at M5/7995A priority 1 on link 200130532; GPS Ref: 378947;209138; Southbound',
#   'Description': 'M5/7995A',
#   'Longitude': -2.30657017844141,
#   'Latitude': 51.7805116883516,
#   'Status': 'Active'},
#  {'Id': '104',
#   'Name': 'MIDAS site at M25/4087B priority 1 on link  200045584; GPS Ref: 555726;172144; Anti-clockwise',
#   'Description': 'M25/4087B',
#   'Longitude': 0.238597016273229,
#   'Latitude': 51.4269111202944,
#   'Status': 'Active'},
#  {'Id': '105',
#   'Name': 'MIDAS site at M42/6536B priority 1 on link 126109002; GPS Ref: 418884;293878; Southbound',
#   'Description': 'M42/6536B',
#   'Longitude': -1.72297868553533,
#   'Latitude': 52.5424493178862,
#   'Status': 'Active'},
#  {'Id': '106',
#   'Name': 'MIDAS site at M25/4919A priority 1 on link 200045691; GPS Ref: 503670;175350; Clockwise',
#   'Description': 'M25/4919A',
#   'Longitude': -0.508905037305114,
#   'Latitude': 51.467633543573,
#   'Status': 'Active'},
#  {'Id': '107',
#   'Name': 'MIDAS site at M11/6349A priority 1 on link 200021668; GPS Ref: 549190;210481; Northbound',
#   'Description': 'M11/6349A',
#   'Longitude': 0.160947832356396,
#   'Latitude': 51.7731301938751,
#   'Status': 'Inactive'},
#  {'Id': '108',
#   'Name': 'MIDAS site at M1/3554B priority 1 on link 107032501; GPS Ref: 454580;300924; Southbound',
#   'Description': 'M1/3554B',
#   'Longitude': -1.19552125249574,
#   'Latitude': 52.6033870930435,
#   'Status': 'Inactive'},
#  {'Id': '109',
#   'Name': 'MIDAS site at M2/8534A priority 1 on link 200009322; GPS Ref: 575407;161900; Eastbound',
#   'Description': 'M2/8534A',
#   'Longitude': 0.516358405675755,
#   'Latitude': 51.3291445048432,
#   'Status': 'Active'},
#  {'Id': '110',
#   'Name': 'MIDAS site at M4/2188B priority 1 on link 125039801; GPS Ref: 513275;178026; Eastbound',
#   'Description': 'M4/2188B',
#   'Longitude': -0.369826643551931,
#   'Latitude': 51.4898454617231,
#   'Status': 'Active'},
#  {'Id': '111',
#   'Name': 'MIDAS site at M1/3916A priority 5 on link 199017201; GPS Ref: 447273;333581; Northbound',
#   'Description': 'M1/3916A',
#   'Longitude': -1.29871011353994,
#   'Latitude': 52.8976210156665,
#   'Status': 'Inactive'},
#  {'Id': '112',
#   'Name': 'MIDAS site at M6/7200B priority 1 on link 117005501; GPS Ref: 354921;401886; Southbound',
#   'Description': 'M6/7200B',
#   'Longitude': -2.68123333060533,
#   'Latitude': 53.5117267154183,
#   'Status': 'Inactive'},
#  {'Id': '113',
#   'Name': 'MIDAS site at M4/3689A priority 1 on link 102004001; GPS Ref: 376295;178134; Westbound',
#   'Description': 'M4/3689A',
#   'Longitude': -2.34289978253983,
#   'Latitude': 51.5016385595349,
#   'Status': 'Active'},
#  {'Id': '114',
#   'Name': 'MIDAS site at M1/3844A priority 1 on link 107031401; GPS Ref: 447463;326776; Northbound',
#   'Description': 'M1/3844A',
#   'Longitude': -1.29687438028578,
#   'Latitude': 52.8364364574098,
#   'Status': 'Inactive'},
#  {'Id': '115',
#   'Name': 'MIDAS site at A1M/9513A priority 1 on link 120006301; GPS Ref: 428279;554033; Northbound',
#   'Description': 'A1M/9513A',
#   'Longitude': -1.560786107074,
#   'Latitude': 54.8802681834031,
#   'Status': 'Active'},
#  {'Id': '116',
#   'Name': 'MIDAS site at M25/5295J priority 1 on link 199001501; GPS Ref: 518829;203302; Clockwise',
#   'Description': 'M25/5295J',
#   'Longitude': -0.281309157518345,
#   'Latitude': 51.7158743457545,
#   'Status': 'Active'},
#  {'Id': '117',
#   'Name': 'MIDAS site at M4/2646A priority 1 on link 105004401; GPS Ref: 472772;168722; Westbound',
#   'Description': 'M4/2646A',
#   'Longitude': -0.954985193468347,
#   'Latitude': 51.4128586723485,
#   'Status': 'Inactive'},
#  {'Id': '118',
#   'Name': 'MIDAS site at M60/9200B priority 1 on link 115023101; GPS Ref: 375030;399277; Anti-clockwise',
#   'Description': 'M60/9200B',
#   'Longitude': -2.37780138324264,
#   'Latitude': 53.4896216973523,
#   'Status': 'Inactive'},
#  {'Id': '119',
#   'Name': 'MIDAS site at M1/4037B priority 1 on link 107033101; GPS Ref: 451653;344314; Southbound',
#   'Description': 'M1/4037B',
#   'Longitude': -1.23190329827427,
#   'Latitude': 52.9936921282007,
#   'Status': 'Active'},
#  {'Id': '120',
#   'Name': 'MIDAS site at M1/3920A priority 7 on link 199017201; GPS Ref: 447263;333980; Northbound',
#   'Description': 'M1/3920A',
#   'Longitude': -1.29880098881557,
#   'Latitude': 52.901208360064,
#   'Status': 'Inactive'},
#  {'Id': '121',
#   'Name': 'MIDAS site at M4/2302B priority 3 on link 199003201; GPS Ref: 502117;178175; Eastbound',
#   'Description': 'M4/2302B',
#   'Longitude': -0.530439284966493,
#   'Latitude': 51.4933088738952,
#   'Status': 'Inactive'},
#  {'Id': '122',
#   'Name': 'MIDAS site at M62/1758A priority 1 on link 116031802; GPS Ref: 399043;414844; Eastbound',
#   'Description': 'M62/1758A',
#   'Longitude': -2.01594440065455,
#   'Latitude': 53.6301380076137,
#   'Status': 'Active'},
#  {'Id': '123',
#   'Name': 'MIDAS site at M1/3789B priority 2 on link 107030601; GPS Ref: 448071;321631; Southbound',
#   'Description': 'M1/3789B',
#   'Longitude': -1.28860407477238,
#   'Latitude': 52.7901352574151,
#   'Status': 'Active'},
#  {'Id': '124',
#   'Name': 'MIDAS site at M25/5316B priority 1 on link 199002701; GPS Ref: 520813;202208; Anti-clockwise',
#   'Description': 'M25/5316B',
#   'Longitude': -0.252983829772872,
#   'Latitude': 51.7056183216442,
#   'Status': 'Active'},
#  {'Id': '125',
#   'Name': 'MIDAS site at M1/4647A priority 1 on link 116025801; GPS Ref: 437103;394542; Northbound',
#   'Description': 'M1/4647A',
#   'Longitude': -1.44283749198875,
#   'Latitude': 53.4463628432432,
#   'Status': 'Inactive'},
#  {'Id': '126',
#   'Name': 'MIDAS site at M20/6502L priority 1 on link 104028101; GPS Ref: 569281;159343; Westbound',
#   'Description': 'M20/6502L',
#   'Longitude': 0.427301099069061,
#   'Latitude': 51.3080280687437,
#   'Status': 'Inactive'},
#  {'Id': '127',
#   'Name': 'MIDAS site at M1/3714B priority 1 on link 126024001; GPS Ref: 448569;314367; Southbound',
#   'Description': 'M1/3714B',
#   'Longitude': -1.28229217689948,
#   'Latitude': 52.724795635042,
#   'Status': 'Active'},
#  {'Id': '128',
#   'Name': 'MIDAS site at M42/6602B priority 1 on link 111023101; GPS Ref: 423136;298734; Southbound',
#   'Description': 'M42/6602B',
#   'Longitude': -1.65994741186594,
#   'Latitude': 52.5859414566433,
#   'Status': 'Inactive'},
#  {'Id': '129',
#   'Name': 'MIDAS site at M6/7536A priority 1 on link 117016001; GPS Ref: 356135;433089; Northbound',
#   'Description': 'M6/7536A',
#   'Longitude': -2.66734107099392,
#   'Latitude': 53.7922687423795,
#   'Status': 'Active'},
#  {'Id': '130',
#   'Name': 'MIDAS site at M1/4662B priority 1 on link 116025002; GPS Ref: 436834;396021; Southbound',
#   'Description': 'M1/4662B',
#   'Longitude': -1.44671547561399,
#   'Latitude': 53.4596752783534,
#   'Status': 'Inactive'},
#  {'Id': '131',
#   'Name': 'MIDAS site at M42/6598A priority 1 on link 111023401; GPS Ref: 422830;298492; Northbound',
#   'Description': 'M42/6598A',
#   'Longitude': -1.66448032227882,
#   'Latitude': 52.5837787432225,
#   'Status': 'Inactive'},
#  {'Id': '132',
#   'Name': 'MIDAS site at M42/6694B priority 1 on link 111022301; GPS Ref: 428080;306340; Southbound',
#   'Description': 'M42/6694B',
#   'Longitude': -1.58633478756029,
#   'Latitude': 52.6540835299817,
#   'Status': 'Inactive'},
#  {'Id': '133',
#   'Name': 'MIDAS site at M42/6277A priority 1 on link 111001801; GPS Ref: 411633;272234; Northbound',
#   'Description': 'M42/6277A',
#   'Longitude': -1.83064033043801,
#   'Latitude': 52.3480710350191,
#   'Status': 'Active'},
#  {'Id': '134',
#   'Name': 'MIDAS site at M60/9492A priority 1 on link 115028201; GPS Ref: 391063;395667; Clockwise',
#   'Description': 'M60/9492A',
#   'Longitude': -2.1360583677519,
#   'Latitude': 53.4576935244612,
#   'Status': 'Active'},
#  {'Id': '135',
#   'Name': 'MIDAS site at M4/2979B priority 1 on link 200110982; GPS Ref: 442016;172622; Eastbound',
#   'Description': 'M4/2979B',
#   'Longitude': -1.39672960093627,
#   'Latitude': 51.4510296413867,
#   'Status': 'Active'},
#  {'Id': '136',
#   'Name': 'MIDAS site at M4/2368A priority 2 on link 105008101; GPS Ref: 496430;179050; Westbound',
#   'Description': 'M4/2368A',
#   'Longitude': -0.612093069827066,
#   'Latitude': 51.5021717889616,
#   'Status': 'Inactive'},
#  {'Id': '137',
#   'Name': 'MIDAS site at M4/3188A priority 1 on link 102005102; GPS Ref: 423643;180072; Westbound',
#   'Description': 'M4/3188A',
#   'Longitude': -1.66063282508525,
#   'Latitude': 51.5190777077866,
#   'Status': 'Active'},
#  {'Id': '138',
#   'Name': 'MIDAS site at M25/4546A priority 13 on link 199131301; GPS Ref: 522867;153119; Clockwise',
#   'Description': 'M25/4546A',
#   'Longitude': -0.240337912305665,
#   'Latitude': 51.2639936126598,
#   'Status': 'Active'},
#  {'Id': '139',
#   'Name': 'MIDAS site at M42/6504B priority 1 on link 126109601; GPS Ref: 418729;290845; Southbound',
#   'Description': 'M42/6504B',
#   'Longitude': -1.72543431237928,
#   'Latitude': 52.5151881598434,
#   'Status': 'Active'},
#  {'Id': '140',
#   'Name': 'MIDAS site at M18/7641A priority 1 on link 116009301; GPS Ref: 456091;398007; Northbound',
#   'Description': 'M18/7641A',
#   'Longitude': -1.15636356825352,
#   'Latitude': 53.4758318036165,
#   'Status': 'Active'},
#  {'Id': '141',
#   'Name': 'MIDAS site at M5/7050A priority 1 on link 112009701; GPS Ref: 401763;290395; Southbound',
#   'Description': 'M5/7050A',
#   'Longitude': -1.97544654920905,
#   'Latitude': 52.5114578087907,
#   'Status': 'Active'},
#  {'Id': '142',
#   'Name': 'MIDAS site at M6/6689A priority 9 on link 123008101; GPS Ref: 377603;359903; Northbound',
#   'Description': 'M6/6689A',
#   'Longitude': -2.33622987039818,
#   'Latitude': 53.1358238823146,
#   'Status': 'Inactive'},
#  {'Id': '143',
#   'Name': 'MIDAS site at M62/1612A priority 1 on link 115032402; GPS Ref: 386530;408992; Eastbound',
#   'Description': 'M62/1612A',
#   'Longitude': -2.20490264677245,
#   'Latitude': 53.5773651156279,
#   'Status': 'Inactive'},
#  {'Id': '144',
#   'Name': 'MIDAS site at M25/4681A priority 1 on link 200047926; GPS Ref: 511963;157575; Clockwise',
#   'Description': 'M25/4681A',
#   'Longitude': -0.395159816936683,
#   'Latitude': 51.3062892566012,
#   'Status': 'Active'},
#  {'Id': '145',
#   'Name': 'MIDAS site at M1/4841J priority 1 on link 116009801; GPS Ref: 429874;411690; Northbound',
#   'Description': 'M1/4841J',
#   'Longitude': -1.55004775990399,
#   'Latitude': 53.6009473966222,
#   'Status': 'Active'},
#  {'Id': '146',
#   'Name': 'MIDAS site at M27/9160J priority 1 on link 103007701; GPS Ref: 441610;117958; Eastbound',
#   'Description': 'M27/9160J',
#   'Longitude': -1.40890127970687,
#   'Latitude': 50.9595442229314,
#   'Status': 'Active'},
#  {'Id': '147',
#   'Name': 'MIDAS site at A38/4508B priority 1 on link 114009501; GPS Ref: 436592;340526; Southbound',
#   'Description': 'A38/4508B',
#   'Longitude': -1.45669925663961,
#   'Latitude': 52.9608791899443,
#   'Status': 'Inactive'},
#  {'Id': '148',
#   'Name': 'MIDAS site at M1/4503B priority 1 on link 116007103; GPS Ref: 448122;387669; Southbound',
#   'Description': 'M1/4503B',
#   'Longitude': -1.27799250918992,
#   'Latitude': 53.3837023342715,
#   'Status': 'Active'},
#  {'Id': '149',
#   'Name': 'MIDAS site at M1/3211A priority 1 on link 123017001; GPS Ref: 459988;267927; Northbound',
#   'Description': 'M1/3211A',
#   'Longitude': -1.12159198119005,
#   'Latitude': 52.3062083051194,
#   'Status': 'Inactive'},
#  {'Id': '150',
#   'Name': 'MIDAS site at M25/5015A priority 1 on link 108032801; GPS Ref: 502426;184608; Clockwise',
#   'Description': 'M25/5015A',
#   'Longitude': -0.524120572989834,
#   'Latitude': 51.5510760788832,
#   'Status': 'Active'},
#  {'Id': '151',
#   'Name': 'MIDAS site at M1/2840B priority 1 on link 108019802; GPS Ref: 486327;243087; Southbound',
#   'Description': 'M1/2840B',
#   'Longitude': -0.741690013729999,
#   'Latitude': 52.0794322666846,
#   'Status': 'Inactive'},
#  {'Id': '152',
#   'Name': 'MIDAS site at M5/7970B priority 1 on link 200045240; GPS Ref: 380337;211237; Northbound',
#   'Description': 'M5/7970B',
#   'Longitude': -2.28654123759167,
#   'Latitude': 51.7994348163404,
#   'Status': 'Active'},
#  {'Id': '153',
#   'Name': 'MIDAS site at A1M/9790A priority 1 on link 118013401; GPS Ref: 440738;457716; Northbound',
#   'Description': 'A1M/9790A',
#   'Longitude': -1.37982028374693,
#   'Latitude': 54.013871859381,
#   'Status': 'Active'},
#  {'Id': '154',
#   'Name': 'MIDAS site at A1M/9362B priority 1 on link 108008701; GPS Ref: 522428;212344; Southbound',
#   'Description': 'A1M/9362B',
#   'Longitude': -0.226058502767254,
#   'Latitude': 51.7963604052188,
#   'Status': 'Active'},
#  {'Id': '155',
#   'Name': 'MIDAS site at M25/4832J priority 1 on link 103048901; GPS Ref: 502001;167383; Clockwise',
#   'Description': 'M25/4832J',
#   'Longitude': -0.535216065021046,
#   'Latitude': 51.3963228410662,
#   'Status': 'Active'},
#  {'Id': '156',
#   'Name': 'MIDAS site at M1/4592A priority 1 on link 116026901; GPS Ref: 440407;390154; Northbound',
#   'Description': 'M1/4592A',
#   'Longitude': -1.3936557297314,
#   'Latitude': 53.4066810268822,
#   'Status': 'Inactive'},
#  {'Id': '157',
#   'Name': 'MIDAS site at M40/8509L priority 1 on link 200055521; GPS Ref: 485048;191040; Southbound',
#   'Description': 'M40/8509L',
#   'Longitude': -0.773134129004326,
#   'Latitude': 51.6117802702978,
#   'Status': 'Active'},
#  {'Id': '158',
#   'Name': 'MIDAS site at M4/3293A priority 1 on link 102005301; GPS Ref: 413683;182400; Westbound',
#   'Description': 'M4/3293A',
#   'Longitude': -1.80408963394933,
#   'Latitude': 51.5403371454078,
#   'Status': 'Active'},
#  {'Id': '159',
#   'Name': 'MIDAS site at M1/4158A priority 1 on link 114008001; GPS Ref: 446648;354932; Northbound',
#   'Description': 'M1/4158A',
#   'Longitude': -1.3049300667832,
#   'Latitude': 53.0895895104071,
#   'Status': 'Active'},
#  {'Id': '160',
#   'Name': 'MIDAS site at M42/6289B priority 1 on link 111001702; GPS Ref: 412795;272148; Southbound',
#   'Description': 'M42/6289B',
#   'Longitude': -1.81358511063377,
#   'Latitude': 52.3472722828008,
#   'Status': 'Active'},
#  {'Id': '161',
#   'Name': 'MIDAS site at M61/2347A priority 1 on link 117007704; GPS Ref: 357814;426148; Northbound',
#   'Description': 'M61/2347A',
#   'Longitude': -2.64090429624218,
#   'Latitude': 53.7300266420828,
#   'Status': 'Active'},
#  {'Id': '162',
#   'Name': 'MIDAS site at M25/4463K priority 1 on link 103066002; GPS Ref: 530433;153279; Clockwise',
#   'Description': 'M25/4463K',
#   'Longitude': -0.131897469676738,
#   'Latitude': 51.2637526090361,
#   'Status': 'Active'},
#  {'Id': '163',
#   'Name': 'MIDAS site at M4/3331B priority 1 on link 102005401; GPS Ref: 410009;183068; Eastbound',
#   'Description': 'M4/3331B',
#   'Longitude': -1.85704686070463,
#   'Latitude': 51.5464200966305,
#   'Status': 'Active'},
#  {'Id': '164',
#   'Name': 'MIDAS site at A14/0070B priority 1 on link 107029602; GPS Ref: 462834;277654; Westbound',
#   'Description': 'A14/0070B',
#   'Longitude': -1.07804136724102,
#   'Latitude': 52.3933268401305,
#   'Status': 'Inactive'},
#  {'Id': '165',
#   'Name': 'MIDAS site at A1M/9763B priority 1 on link 122000301; GPS Ref: 441857;455089; Southbound',
#   'Description': 'A1M/9763B',
#   'Longitude': -1.36310562522243,
#   'Latitude': 53.9901737523202,
#   'Status': 'Active'},
#  {'Id': '166',
#   'Name': 'MIDAS site at M1/4849B priority 1 on link 116018202; GPS Ref: 429724;412478; Southbound',
#   'Description': 'M1/4849B',
#   'Longitude': -1.55223952000117,
#   'Latitude': 53.6080383358085,
#   'Status': 'Active'},
#  {'Id': '167',
#   'Name': 'MIDAS site at A1M/9411B priority 1 on link 200014152; GPS Ref: 446995;424913; Southbound',
#   'Description': 'A1M/9411B',
#   'Longitude': -1.28935416303615,
#   'Latitude': 53.7185380591633,
#   'Status': 'Active'},
#  {'Id': '168',
#   'Name': 'MIDAS site at M1/5079A priority 1 on link 116023902; GPS Ref: 435349;431323; Northbound',
#   'Description': 'M1/5079A',
#   'Longitude': -1.46508798635694,
#   'Latitude': 53.7770632996564,
#   'Status': 'Inactive'},
#  {'Id': '169',
#   'Name': 'MIDAS site at M61/2347B priority 1 on link 117008102; GPS Ref: 357842;426148; Southbound',
#   'Description': 'M61/2347B',
#   'Longitude': -2.64047992295822,
#   'Latitude': 53.7300289093975,
#   'Status': 'Active'},
#  {'Id': '170',
#   'Name': 'MIDAS site at A2/8369J priority 1 on link 200045742; GPS Ref: 563713;171398; Eastbound',
#   'Description': 'A2/8369J',
#   'Longitude': 0.353037508930245,
#   'Latitude': 51.4179593722875,
#   'Status': 'Active'},
#  {'Id': '171',
#   'Name': 'MIDAS site at M62/2179L priority 1 on link 116020601; GPS Ref: 433707;425844; Westbound',
#   'Description': 'M62/2179L',
#   'Longitude': -1.4905985356828,
#   'Latitude': 53.727928598179,
#   'Status': 'Active'},
#  {'Id': '172',
#   'Name': 'MIDAS site at A1M/9887A priority 1 on link 118013501; GPS Ref: 438698;466904; Northbound',
#   'Description': 'A1M/9887A',
#   'Longitude': -1.40978085862367,
#   'Latitude': 54.0966010952248,
#   'Status': 'Active'},
#  {'Id': '173',
#   'Name': 'MIDAS site at M56/8284B priority 1 on link 110004302; GPS Ref: 366696;384124; Eastbound',
#   'Description': 'M56/8284B',
#   'Longitude': -2.50179581957847,
#   'Latitude': 53.3529601272554,
#   'Status': 'Active'},
#  {'Id': '174',
#   'Name': 'MIDAS site at M27/9148A priority 1 on link 103007402; GPS Ref: 440472;117989; Eastbound',
#   'Description': 'M27/9148A',
#   'Longitude': -1.42510058533902,
#   'Latitude': 50.9599038795125,
#   'Status': 'Active'},
#  {'Id': '175',
#   'Name': 'MIDAS site at M42/6482L priority 1 on link 126109801; GPS Ref: 419326;288851; Southbound',
#   'Description': 'M42/6482L',
#   'Longitude': -1.71675229082771,
#   'Latitude': 52.4972416063519,
#   'Status': 'Active'},
#  {'Id': '176',
#   'Name': 'MIDAS site at M4/3296B priority 1 on link 102005201; GPS Ref: 413386;182402; Eastbound',
#   'Description': 'M4/3296B',
#   'Longitude': -1.80837207606248,
#   'Latitude': 51.5403622096323,
#   'Status': 'Active'},
#  {'Id': '177',
#   'Name': 'MIDAS site at M6/6673A priority 6 on link 123008101; GPS Ref: 377653;358351; Northbound',
#   'Description': 'M6/6673A',
#   'Longitude': -2.3353739474436,
#   'Latitude': 53.1218752843551,
#   'Status': 'Inactive'},
#  {'Id': '178',
#   'Name': 'MIDAS site at M1/3942A priority 1 on link 123013701; GPS Ref: 447146;336274; Northbound',
#   'Description': 'M1/3942A',
#   'Longitude': -1.3002087353909,
#   'Latitude': 52.9218385427192,
#   'Status': 'Active'},
#  {'Id': '179',
#   'Name': 'MIDAS site at M4/3360B priority 1 on link 102004801; GPS Ref: 407388;184287; Eastbound',
#   'Description': 'M4/3360B',
#   'Longitude': -1.89481909115621,
#   'Latitude': 51.5574207423981,
#   'Status': 'Active'},
#  {'Id': '180',
#   'Name': 'MIDAS site at M1/4053B priority 1 on link 107033101; GPS Ref: 451389;345844; Southbound',
#   'Description': 'M1/4053B',
#   'Longitude': -1.23559313826897,
#   'Latitude': 53.0074691453984,
#   'Status': 'Active'},
#  {'Id': '181',
#   'Name': 'MIDAS site at M25/5271A priority 1 on link 199002901; GPS Ref: 516338;202802; Clockwise',
#   'Description': 'M25/5271A',
#   'Longitude': -0.317518697914885,
#   'Latitude': 51.7119022451721,
#   'Status': 'Active'},
#  {'Id': '182',
#   'Name': 'MIDAS site at M42/6626A priority 1 on link 111022201; GPS Ref: 424419;300751; Northbound',
#   'Description': 'M42/6626A',
#   'Longitude': -1.64086145008631,
#   'Latitude': 52.6040174541876,
#   'Status': 'Active'},
#  {'Id': '183',
#   'Name': 'MIDAS site at M1/4166B priority 1 on link 107032001; GPS Ref: 446189;355618; Southbound',
#   'Description': 'M1/4166B',
#   'Longitude': -1.31168476796518,
#   'Latitude': 53.0957954694617,
#   'Status': 'Inactive'},
#  {'Id': '184',
#   'Name': 'MIDAS site at M1/5022B priority 1 on link 116021701; GPS Ref: 432043;427655; Southbound',
#   'Description': 'M1/5022B',
#   'Longitude': -1.51563163459269,
#   'Latitude': 53.7443099119214,
#   'Status': 'Active'},
#  {'Id': '185',
#   'Name': 'MIDAS site at M4/3638B priority 1 on link 123001701; GPS Ref: 381024;179928; Eastbound',
#   'Description': 'M4/3638B',
#   'Longitude': -2.27486757121409,
#   'Latitude': 51.5179489978239,
#   'Status': 'Active'},
#  {'Id': '186',
#   'Name': 'MIDAS site at M25/5825A priority 1 on link 199065401; GPS Ref: 557864;182897; Clockwise',
#   'Description': 'M25/5825A',
#   'Longitude': 0.274124640208291,
#   'Latitude': 51.5229305800508,
#   'Status': 'Active'},
#  {'Id': '187',
#   'Name': 'MIDAS site at M6/6656B priority 1 on link 110005102; GPS Ref: 377380;356606; Southbound',
#   'Description': 'M6/6656B',
#   'Longitude': -2.33932975533586,
#   'Latitude': 53.1061781165328,
#   'Status': 'Inactive'},
#  {'Id': '188',
#   'Name': 'MIDAS site at M1/5008L priority 1 on link 116022201; GPS Ref: 431751;426305; Westbound',
#   'Description': 'M1/5008L',
#   'Longitude': -1.52019685763864,
#   'Latitude': 53.7321943031426,
#   'Status': 'Active'},
#  {'Id': '189',
#   'Name': 'MIDAS site at A38/4696A priority 1 on link 200124310; GPS Ref: 443770;355310; Northbound',
#   'Description': 'A38/4696A',
#   'Longitude': -1.34784805403429,
#   'Latitude': 53.0932302662112,
#   'Status': 'Active'},
#  {'Id': '190',
#   'Name': 'MIDAS site at M1/4174M priority 1 on link 114007802; GPS Ref: 445564;356076; Southbound',
#   'Description': 'M1/4174M',
#   'Longitude': -1.3209528147206,
#   'Latitude': 53.099965859526,
#   'Status': 'Inactive'},
#  {'Id': '191',
#   'Name': 'MIDAS site at M42/6416M priority 1 on link 112006601; GPS Ref: 419549;282300; Southbound',
#   'Description': 'M42/6416M',
#   'Longitude': -1.71384959264884,
#   'Latitude': 52.4383404116617,
#   'Status': 'Active'},
#  {'Id': '192',
#   'Name': 'MIDAS site at M1/3135A priority 6 on link 123016901(Non-monitoring MIDAS); GPS Ref: 463910;261514; Northbound',
#   'Description': 'M1/3135A',
#   'Longitude': -1.06529045874873,
#   'Latitude': 52.2481191499722,
#   'Status': 'Inactive'},
#  {'Id': '193',
#   'Name': 'MIDAS site at M25/4387A priority 1 on link 199121802; GPS Ref: 537797;153642; Clockwise',
#   'Description': 'M25/4387A',
#   'Longitude': -0.026276149531773,
#   'Latitude': 51.2652831872562,
#   'Status': 'Active'},
#  {'Id': '194',
#   'Name': 'MIDAS site at M62/1962B priority 1 on link 116033502; GPS Ref: 416951;422669; Westbound',
#   'Description': 'M62/1962B',
#   'Longitude': -1.74472982593984,
#   'Latitude': 53.7002004500296,
#   'Status': 'Active'},
#  {'Id': '195',
#   'Name': 'MIDAS site at M1/4283J priority 1 on link 114007301; GPS Ref: 445260;366694; Northbound',
#   'Description': 'M1/4283J',
#   'Longitude': -1.32399669239401,
#   'Latitude': 53.1954285328942,
#   'Status': 'Inactive'},
#  {'Id': '196',
#   'Name': 'MIDAS site at M1/2949A priority 7 on link 108019502; GPS Ref: 478975;251252; Northbound',
#   'Description': 'M1/2949A',
#   'Longitude': -0.847060010187666,
#   'Latitude': 52.1539236567407,
#   'Status': 'Inactive'},
#  {'Id': '197',
#   'Name': 'MIDAS site at M1/4081B priority 1 on link 107033101; GPS Ref: 450543;348461; Southbound',
#   'Description': 'M1/4081B',
#   'Longitude': -1.24779117915923,
#   'Latitude': 53.0310716975615,
#   'Status': 'Active'},
#  {'Id': '198',
#   'Name': 'MIDAS site at M6/6943B priority 4 on link 110006401; GPS Ref: 368539;381713; Southbound',
#   'Description': 'M6/6943B',
#   'Longitude': -2.47386816834708,
#   'Latitude': 53.3314026769953,
#   'Status': 'Inactive'},
#  {'Id': '199',
#   'Name': 'MIDAS site at M25/4916A priority 1 on link 200045691; GPS Ref: 503510;175090; Clockwise',
#   'Description': 'M25/4916A',
#   'Longitude': -0.511283674897309,
#   'Latitude': 51.4653257344343,
#   'Status': 'Active'},
#  {'Id': '200',
#   'Name': 'MIDAS site at M62/1355B  priority 1 on link 199086201; GPS Ref: 369015;393688; Westbound',
#   'Description': 'M62/1355B',
#   'Longitude': -2.46790104368682,
#   'Latitude': 53.4390654724309,
#   'Status': 'Inactive'},
#  {'Id': '201',
#   'Name': 'MIDAS site at M1/5115M priority 1 on link 116023502; GPS Ref: 437836;432670; Southbound',
#   'Description': 'M1/5115M',
#   'Longitude': -1.42718767356945,
#   'Latitude': 53.7889954163897,
#   'Status': 'Active'},
#  {'Id': '202',
#   'Name': 'MIDAS site at M1/4627B priority 1 on link 116025601; GPS Ref: 438306;393094; Southbound',
#   'Description': 'M1/4627B',
#   'Longitude': -1.42490129777095,
#   'Latitude': 53.4332625162595,
#   'Status': 'Inactive'},
#  {'Id': '203',
#   'Name': 'MIDAS site at M25/4712J priority 1 on link 200047931; GPS Ref: 509129;158559; Clockwise',
#   'Description': 'M25/4712J',
#   'Longitude': -0.435498765001495,
#   'Latitude': 51.315683798588,
#   'Status': 'Active'},
#  {'Id': '204',
#   'Name': 'MIDAS site at M4/3143A priority 1 on link 102005102; GPS Ref: 427886;178680; Westbound',
#   'Description': 'M4/3143A',
#   'Longitude': -1.59959181439359,
#   'Latitude': 51.5063693815139,
#   'Status': 'Active'},
#  {'Id': '205',
# ...
#   'Description': 'M1/2482M',
#   'Longitude': -0.421472272294345,
#   'Latitude': 51.8469569777524,
#   'Status': 'Active'},
#  {'Id': '934',
#   'Name': 'MIDAS site at M60/9024B priority 1 on link 115027201; GPS Ref: 386259;389483; Anti-clockwise',
#   'Description': 'M60/9024B',
#   'Longitude': -2.20813483346913,
#   'Latitude': 53.4020044370929,
#   'Status': 'Active'},
#  {'Id': '935',
#   'Name': 'MIDAS site at M42/6252B priority 1 on link 111001301; GPS Ref: 409169;272672; Southbound',
#   'Description': 'M42/6252B',
#   'Longitude': -1.86680038963064,
#   'Latitude': 52.3520543997898,
#   'Status': 'Active'},
#  {'Id': '936',
#   'Name': 'MIDAS site at M25/4941A priority 1 on link 200045641; GPS Ref: 504378;177454; Clockwise',
#   'Description': 'M25/4941A',
#   'Longitude': -0.498095245505443,
#   'Latitude': 51.4864156436227,
#   'Status': 'Active'},
#  {'Id': '937',
#   'Name': 'MIDAS site at M1/3316B priority 1 on link 108018301; GPS Ref: 456399;277699; Southbound',
#   'Description': 'M1/3316B',
#   'Longitude': -1.17258749114074,
#   'Latitude': 52.3944310832033,
#   'Status': 'Inactive'},
#  {'Id': '938',
#   'Name': 'MIDAS site at M1/2780B priority 1 on link 108020201; GPS Ref: 491325;239768; Southbound',
#   'Description': 'M1/2780B',
#   'Longitude': -0.669664742535789,
#   'Latitude': 52.0488001524407,
#   'Status': 'Inactive'},
#  {'Id': '939',
#   'Name': 'MIDAS site at M62/1650B priority 1 on link 115032802; GPS Ref: 389922;410183; Westbound',
#   'Description': 'M62/1650B',
#   'Longitude': -2.15371372043731,
#   'Latitude': 53.5881470722354,
#   'Status': 'Inactive'},
#  {'Id': '940',
#   'Name': 'MIDAS site at M6/5783J priority 1 on link 112001301; GPS Ref: 414303;290144; Northbound',
#   'Description': 'M6/5783J',
#   'Longitude': -1.79068444248676,
#   'Latitude': 52.5090185235027,
#   'Status': 'Active'},
#  {'Id': '941',
#   'Name': 'MIDAS site at M1/2945B priority 6 on link 123017901; GPS Ref: 479219;250877; Southbound',
#   'Description': 'M1/2945B',
#   'Longitude': -0.843581623634247,
#   'Latitude': 52.150517945198,
#   'Status': 'Inactive'},
#  {'Id': '942',
#   'Name': 'MIDAS site at M602/6006K priority 1 on link 115022102; GPS Ref: 375285;399211; Eastbound',
#   'Description': 'M602/6006K',
#   'Longitude': -2.37395301707006,
#   'Latitude': 53.4890405474838,
#   'Status': 'Active'},
#  {'Id': '943',
#   'Name': 'MIDAS site at M1/3465B priority 1 on link 107033901; GPS Ref: 456044;292240; Southbound',
#   'Description': 'M1/3465B',
#   'Longitude': -1.17536973777637,
#   'Latitude': 52.5251789347393,
#   'Status': 'Active'},
#  {'Id': '944',
#   'Name': 'MIDAS site at M25/4588B priority 4 on link 199131801; GPS Ref: 519904;156043; Anti-clockwise',
#   'Description': 'M25/4588B',
#   'Longitude': -0.281805535960265,
#   'Latitude': 51.2909037072074,
#   'Status': 'Inactive'},
#  {'Id': '945',
#   'Name': 'MIDAS site at M6/6038B priority 1 on link 112001501; GPS Ref: 396838;303544; Southbound',
#   'Description': 'M6/6038B',
#   'Longitude': -2.04814435765354,
#   'Latitude': 52.6296582998406,
#   'Status': 'Active'},
#  {'Id': '946',
#   'Name': 'MIDAS site at M1/4022B priority 1 on link 123013901; GPS Ref: 450789;343098; Southbound',
#   'Description': 'M1/4022B',
#   'Longitude': -1.24496467388692,
#   'Latitude': 52.9828449315648,
#   'Status': 'Active'},
#  {'Id': '947',
#   'Name': 'MIDAS site at M1/2587B priority 1 on link 108023102; GPS Ref: 503548;226577; Southbound',
#   'Description': 'M1/2587B',
#   'Longitude': -0.495462495313324,
#   'Latitude': 51.9280964293476,
#   'Status': 'Inactive'},
#  {'Id': '948',
#   'Name': 'MIDAS site at M42/6678B priority 1 on link 111022301; GPS Ref: 427221;304993; Southbound',
#   'Description': 'M42/6678B',
#   'Longitude': -1.59914276947996,
#   'Latitude': 52.6420183419669,
#   'Status': 'Active'},
#  {'Id': '949',
#   'Name': 'MIDAS site at M4/2162B priority 1 on link 200127243; GPS Ref: 515638;178759; Eastbound',
#   'Description': 'M4/2162B',
#   'Longitude': -0.335566303487721,
#   'Latitude': 51.4959557927919,
#   'Status': 'Active'},
#  {'Id': '950',
#   'Name': 'MIDAS site at M20/6650L priority 1 on link 104030902; GPS Ref: 582513;154757; Westbound',
#   'Description': 'M20/6650L',
#   'Longitude': 0.614594937156256,
#   'Latitude': 51.2627489736674,
#   'Status': 'Active'},
#  {'Id': '951',
#   'Name': 'MIDAS site at M61/2320J priority 1 on link 117008601; GPS Ref: 358404;423725; Northbound',
#   'Description': 'M61/2320J',
#   'Longitude': -2.63163530858568,
#   'Latitude': 53.7082975216504,
#   'Status': 'Active'},
#  {'Id': '952',
#   'Name': 'MIDAS site at M62/2089B priority 1 on link 116034601; GPS Ref: 425127;426765; Westbound',
#   'Description': 'M62/2089B',
#   'Longitude': -1.6205642586291,
#   'Latitude': 53.736687213571,
#   'Status': 'Active'},
#  {'Id': '953',
#   'Name': 'MIDAS site at M4/2639B priority 1 on link 105005001; GPS Ref: 473399;169053; Eastbound',
#   'Description': 'M4/2639B',
#   'Longitude': -0.945903526085183,
#   'Latitude': 51.4157536975742,
#   'Status': 'Inactive'},
#  {'Id': '954',
#   'Name': 'MIDAS site at M1/5079B priority 1 on link 116024101; GPS Ref: 435359;431301; Southbound',
#   'Description': 'M1/5079B',
#   'Longitude': -1.46493876507108,
#   'Latitude': 53.7768648989823,
#   'Status': 'Inactive'},
#  {'Id': '955',
#   'Name': 'MIDAS site at A2/8336B priority 1 on link 200010457; GPS Ref: 560676;172671; Westbound',
#   'Description': 'A2/8336B',
#   'Longitude': 0.30997626637197,
#   'Latitude': 51.4302646708151,
#   'Status': 'Active'},
#  {'Id': '956',
#   'Name': 'MIDAS site at M25/4617B priority 18 on link 199131801; GPS Ref: 517259;157252; Anti-clockwise',
#   'Description': 'M25/4617B',
#   'Longitude': -0.319324008549641,
#   'Latitude': 51.3023209339097,
#   'Status': 'Active'},
#  {'Id': '957',
#   'Name': 'MIDAS site at M4/2732K priority 1 on link 105004202; GPS Ref: 464937;171571; Westbound',
#   'Description': 'M4/2732K',
#   'Longitude': -1.06710624824026,
#   'Latitude': 51.4394225760558,
#   'Status': 'Inactive'},
#  {'Id': '958',
#   'Name': 'MIDAS site at M1/2566A priority 1 on link 123018501; GPS Ref: 504411;224664; Northbound',
#   'Description': 'M1/2566A',
#   'Longitude': -0.483495305575268,
#   'Latitude': 51.9107416500629,
#   'Status': 'Inactive'},
#  {'Id': '959',
#   'Name': 'MIDAS site at M25/5124M priority 1 on link 199004801; GPS Ref: 504163;196084; Anti-clockwise',
#   'Description': 'M25/5124M',
#   'Longitude': -0.495671516900497,
#   'Latitude': 51.6539090508428,
#   'Status': 'Active'},
#  {'Id': '960',
#   'Name': 'MIDAS site at M6/6016A priority 1 on link 111030401; GPS Ref: 398160;301933; Northbound',
#   'Description': 'M6/6016A',
#   'Longitude': -2.02860369685067,
#   'Latitude': 52.6151821480087,
#   'Status': 'Active'},
#  {'Id': '961',
#   'Name': 'MIDAS site at M5/7421B priority 1 on link 109003001; GPS Ref: 390292;258706; Northbound',
#   'Description': 'M5/7421B',
#   'Longitude': -2.14353870200304,
#   'Latitude': 52.2264825906583,
#   'Status': 'Inactive'},
#  {'Id': '962',
#   'Name': 'MIDAS site at M25/4871B priority 1 on link 103049601; GPS Ref: 501562;171060; Anti-clockwise',
#   'Description': 'M25/4871B',
#   'Longitude': -0.540472088934882,
#   'Latitude': 51.4294531712771,
#   'Status': 'Active'},
#  {'Id': '963',
#   'Name': 'MIDAS site at M25/5453B priority 1 on link 199066501; GPS Ref: 533153;200437; Anti-clockwise',
#   'Description': 'M25/5453B',
#   'Longitude': -0.075177321288034,
#   'Latitude': 51.6869122184108,
#   'Status': 'Active'},
#  {'Id': '964',
#   'Name': 'MIDAS site at M1/3996A priority 1 on link 107033002; GPS Ref: 449437;340940; Northbound',
#   'Description': 'M1/3996A',
#   'Longitude': -1.26542830324086,
#   'Latitude': 52.9635739013301,
#   'Status': 'Active'},
#  {'Id': '965',
#   'Name': 'MIDAS site at M65/4049B priority 0 on link 117015901; GPS Ref: 360000;424784; Westbound',
#   'Description': 'M65/4049B',
#   'Longitude': -2.60759559708311,
#   'Latitude': 53.7179402791281,
#   'Status': 'Active'},
#  {'Id': '966',
#   'Name': 'MIDAS site at M25/4955A priority 1 on link 199004101; GPS Ref: 504572;178762; Clockwise',
#   'Description': 'M25/4955A',
#   'Longitude': -0.494914769369052,
#   'Latitude': 51.4981367784609,
#   'Status': 'Active'},
#  {'Id': '967',
#   'Name': 'MIDAS site at M6/6630A priority 6 on link 123008101; GPS Ref: 377219;354057; Northbound',
#   'Description': 'M6/6630A',
#   'Longitude': -2.34155315957867,
#   'Latitude': 53.0832585211285,
#   'Status': 'Inactive'},
#  {'Id': '968',
#   'Name': 'MIDAS site at M1/4178K priority 1 on link 114007902; GPS Ref: 445208;356368; Northbound',
#   'Description': 'M1/4178K',
#   'Longitude': -1.32622833436196,
#   'Latitude': 53.1026207448277,
#   'Status': 'Inactive'},
#  {'Id': '969',
#   'Name': 'MIDAS site at M4/3847B priority 1 on link 102003601; GPS Ref: 362796;182013; Eastbound',
#   'Description': 'M4/3847B',
#   'Longitude': -2.53778281900407,
#   'Latitude': 51.5357852592985,
#   'Status': 'Active'},
#  {'Id': '970',
#   'Name': 'MIDAS site at M66/4139B priority 1 on link 115016701; GPS Ref: 382924;405792; Northbound',
#   'Description': 'M66/4139B',
#   'Longitude': -2.25918585700014,
#   'Latitude': 53.5484971958887,
#   'Status': 'Active'},
#  {'Id': '971',
#   'Name': 'MIDAS site at M6/5937B priority 1 on link 112004301; GPS Ref: 401639;295542; Southbound',
#   'Description': 'M6/5937B',
#   'Longitude': -1.97725061367103,
#   'Latitude': 52.557729099601,
#   'Status': 'Active'},
#  {'Id': '972',
#   'Name': 'MIDAS site at M69/8248A priority 2 on link 107032602; GPS Ref: 453899;300675; Northbound',
#   'Description': 'M69/8248A',
#   'Longitude': -1.20561579729432,
#   'Latitude': 52.6012167726268,
#   'Status': 'Inactive'},
#  {'Id': '973',
#   'Name': 'MIDAS site at A168/9032B priority 1 on link 118015201; GPS Ref: 438632;473657; Southbound',
#   'Description': 'A168/9032B',
#   'Longitude': -1.40992962367041,
#   'Latitude': 54.1572940798305,
#   'Status': 'Active'},
#  {'Id': '974',
#   'Name': 'MIDAS site at M1/2685B priority 1 on link 200117997; GPS Ref: 499654;235376; Southbound',
#   'Description': 'M1/2685B',
#   'Longitude': -0.549525078825534,
#   'Latitude': 52.0078919999837,
#   'Status': 'Active'},
#  {'Id': '975',
#   'Name': 'MIDAS site at M62/1279A priority 1 on link 199086801; GPS Ref: 361609;392005; Eastbound',
#   'Description': 'M62/1279A',
#   'Longitude': -2.57917720689246,
#   'Latitude': 53.4234499956186,
#   'Status': 'Inactive'},
#  {'Id': '976',
#   'Name': 'MIDAS site at M1/5065B priority 1 on link 116022801; GPS Ref: 434444;430538; Southbound',
#   'Description': 'M1/5065B',
#   'Longitude': -1.4789073282551,
#   'Latitude': 53.7700685000625,
#   'Status': 'Active'},
#  {'Id': '977',
#   'Name': 'MIDAS site at M25/5701B priority 1 on link 200047941; GPS Ref: 555106;193933; Anti-clockwise',
#   'Description': 'M25/5701B',
#   'Longitude': 0.23927014501532,
#   'Latitude': 51.6228488385753,
#   'Status': 'Active'},
#  {'Id': '978',
#   'Name': 'MIDAS site at M25/5238B priority 1 on link 108024301; GPS Ref: 512727;203010; Anti-clockwise',
#   'Description': 'M25/5238B',
#   'Longitude': -0.36969147099284,
#   'Latitude': 51.7145077070832,
#   'Status': 'Active'},
#  {'Id': '979',
#   'Name': 'MIDAS site at M25/5493A priority 1 on link 199064601; GPS Ref: 537149;199871; Clockwise',
#   'Description': 'M25/5493A',
#   'Longitude': -0.017630245000813,
#   'Latitude': 51.6808653800857,
#   'Status': 'Active'},
#  {'Id': '980',
#   'Name': 'MIDAS site at M6/7072B priority 1 on link 199087701; GPS Ref: 362954;392481; Southbound',
#   'Description': 'M6/7072B',
#   'Longitude': -2.55899498066731,
#   'Latitude': 53.4278249398776,
#   'Status': 'Active'},
#  {'Id': '981',
#   'Name': 'MIDAS site at M25/4352B priority 1 on link 123011501; GPS Ref: 541157;154119; Anti-clockwise',
#   'Description': 'M25/4352B',
#   'Longitude': 0.022040241116137,
#   'Latitude': 51.2687482893127,
#   'Status': 'Inactive'},
#  {'Id': '982',
#   'Name': 'MIDAS site at M25/4592B priority 5 on link 199131801; GPS Ref: 519579;156149; Anti-clockwise',
#   'Description': 'M25/4592B',
#   'Longitude': -0.286428780884494,
#   'Latitude': 51.2919247247446,
#   'Status': 'Active'},
#  {'Id': '983',
#   'Name': 'MIDAS site at M1/3949B priority 1 on link 199017102; GPS Ref: 447140;336946; Southbound',
#   'Description': 'M1/3949B',
#   'Longitude': -1.30020075408253,
#   'Latitude': 52.927879450473,
#   'Status': 'Active'},
#  {'Id': '984',
#   'Name': 'MIDAS site at M25/5811B priority 1 on link 199056101; GPS Ref: 558235;184265; Anti-clockwise',
#   'Description': 'M25/5811B',
#   'Longitude': 0.280081831976932,
#   'Latitude': 51.5351176064162,
#   'Status': 'Active'},
#  {'Id': '985',
#   'Name': 'MIDAS site at M5/7837B priority 1 on link 199103401; GPS Ref: 389675;220046; Northbound',
#   'Description': 'M5/7837B',
#   'Longitude': -2.15139134024877,
#   'Latitude': 51.8788885713152,
#   'Status': 'Active'},
#  {'Id': '986',
#   'Name': 'MIDAS site at M25/5479L priority 1 on link 199055501; GPS Ref: 535752;200005; Anti-clockwise',
#   'Description': 'M25/5479L',
#   'Longitude': -0.037771699430137,
#   'Latitude': 51.6824084700074,
#   'Status': 'Active'},
#  {'Id': '987',
#   'Name': 'MIDAS site at A14/0387B priority 1 on link 108036901; GPS Ref: 490795;276498; Westbound',
#   'Description': 'A14/0387B',
#   'Longitude': -0.667555621207182,
#   'Latitude': 52.3790184878712,
#   'Status': 'Active'},
#  {'Id': '988',
#   'Name': 'MIDAS site at A1M/9525B priority 1 on link 200013590; GPS Ref: 443883;434136; Southbound',
#   'Description': 'A1M/9525B',
#   'Longitude': -1.33520006345367,
#   'Latitude': 53.8016981690992,
#   'Status': 'Active'},
#  {'Id': '989',
#   'Name': 'MIDAS site at A14/0089B priority 1 on link 107029602; GPS Ref: 464682;277986; Westbound',
#   'Description': 'A14/0089B',
#   'Longitude': -1.05082427973927,
#   'Latitude': 52.3960961962281,
#   'Status': 'Inactive'},
#  {'Id': '990',
#   'Name': 'MIDAS site at M60/9441A priority 5 on link 200105362; GPS Ref: 391916;400001; Clockwise',
#   'Description': 'M60/9441A',
#   'Longitude': -2.12332540904003,
#   'Latitude': 53.496663192701,
#   'Status': 'Active'},
#  {'Id': '991',
#   'Name': 'MIDAS site at M5/9318B priority 1 on link 101002601; GPS Ref: 304278;113359; Northbound',
#   'Description': 'M5/9318B',
#   'Longitude': -3.36294058169984,
#   'Latitude': 50.9117258399951,
#   'Status': 'Active'},
#  {'Id': '992',
#   'Name': 'MIDAS site at M1/4150A priority 1 on link 114008001; GPS Ref: 447078;354256; Northbound',
#   'Description': 'M1/4150A',
#   'Longitude': -1.2986087508395,
#   'Latitude': 53.0834756086988,
#   'Status': 'Active'},
#  {'Id': '993',
#   'Name': 'MIDAS site at A1M/9397M priority 1 on link 200014149; GPS Ref: 447612;423715; Southbound',
#   'Description': 'A1M/9397M',
#   'Longitude': -1.28018836783505,
#   'Latitude': 53.7077153872953,
#   'Status': 'Active'},
#  {'Id': '994',
#   'Name': 'MIDAS site at M4/2574A priority 1 on link 105005202; GPS Ref: 479469;170609; Westbound',
#   'Description': 'M4/2574A',
#   'Longitude': -0.85828888273025,
#   'Latitude': 51.4289248388865,
#   'Status': 'Inactive'},
#  {'Id': '995',
#   'Name': 'MIDAS site at M5/7008L priority 1 on link 112004302; GPS Ref: 402805;294454; Southbound',
#   'Description': 'M5/7008L',
#   'Longitude': -1.96006109890803,
#   'Latitude': 52.5479436975488,
#   'Status': 'Active'},
#  {'Id': '996',
#   'Name': 'MIDAS site at M5/7978B priority 1 on link 102016201; GPS Ref: 379821;210629; Northbound',
#   'Description': 'M5/7978B',
#   'Longitude': -2.29398841231822,
#   'Latitude': 51.793949776021,
#   'Status': 'Active'},
#  {'Id': '997',
#   'Name': 'MIDAS site at M1/4284A priority 1 on link 114008401; GPS Ref: 445291;366756; Northbound',
#   'Description': 'M1/4284A',
#   'Longitude': -1.3235239440106,
#   'Latitude': 53.1959831567679,
#   'Status': 'Inactive'},
#  {'Id': '998',
#   'Name': 'MIDAS site at A1M/9404L priority 1 on link 200017493; GPS Ref: 446884;424144; Westbound',
#   'Description': 'A1M/9404L',
#   'Longitude': -1.29115169006158,
#   'Latitude': 53.7116366802162,
#   'Status': 'Active'},
#  {'Id': '999',
#   'Name': 'MIDAS site at M1/3939B priority 1 on link 199017301; GPS Ref: 447188;335963; Southbound',
#   'Description': 'M1/3939B',
#   'Longitude': -1.29962911397163,
#   'Latitude': 52.9190393901494,
#   'Status': 'Inactive'},
#  {'Id': '1000',
#   'Name': 'MIDAS site at M1/3495B priority 23 on link 107033901; GPS Ref: 455311;295102; Southbound',
#   'Description': 'M1/3495B',
#   'Longitude': -1.18569696125564,
#   'Latitude': 52.5509802731377,
#   'Status': 'Inactive'},
#  ...]

# %% [markdown]
# ## Helper Functions

# %%
def get_quality_area(sites,
                     max_lat=math.inf,
                     max_long=math.inf,
                     min_lat=-math.inf,
                     min_long=-math.inf,
                     start_date='01062021',
                     end_date = '15062022',
                     quality_threshold = 90):
    '''
    Returns a dataframe of Traffic Count sites in the specified area and time with sufficent reporting quality
            Parameters:
                    max_lat, max_long, min_lat, min_long (int): Coordinates defining the rectangular area of interest. Default is entire globe.
                    start_date, end_date (str): Strings of the start and end dates of our search ddmmyy
                    quality_threshold (int): Only indclude sites that have at least quality_threshold % of times reporting data
            Returns:
                    quality_area_sites_df (dataframe): Report high quality sites, cols are: Id, Name, Description, Longitude, Latitude, Status
    '''
    # Convert sites query into df and filter onto our area
    sites_df = pd.DataFrame(data = sites)
    area_sites_df = sites_df.loc[(min_long < sites_df.Longitude) & (sites_df.Longitude < max_long)
                                & (min_lat < sites_df.Latitude) & (sites_df.Latitude < max_lat)]
    area_sites_df = area_sites_df.reset_index(drop=True)
    area_ids = list(area_sites_df.Id)
    
    # Next filter onto sites with good quality data:
    quality_responces = []
    for site_id in tqdm(area_ids):
        url_text = f"https://webtris.highwaysengland.co.uk/api/v1/quality/overall?sites={site_id}&start_date={start_date}&end_date={end_date}"
        with urllib.request.urlopen(url_text) as url:
            responce = json.loads(url.read().decode())
        quality_responces.append(responce)
        
    # We only want sites with quality greater than threshold
    good_quality_ids = []
    for responce in quality_responces:
        if responce['data_quality'] >= quality_threshold:
            good_quality_ids.append(responce['sites'])

    quality_area_sites_df = area_sites_df.loc[area_sites_df.Id.isin(good_quality_ids)]
    quality_area_sites_df = quality_area_sites_df.reset_index(drop=True)
    
    print('quality_area_sites_df: {}'.format(quality_area_sites_df))
    return quality_area_sites_df

# %%
def daily_report_query_url(site_id, page_num, start_date = '15062021', end_date = '15062022'):
    '''Generates the query url for page page_num of traffic reporting of site site_id'''
    query_url = f"https://webtris.highwaysengland.co.uk/api/v1/reports/Daily?sites={site_id}&start_date={start_date}&end_date={end_date}&page={page_num}&page_size=10000"
    return query_url

# %%
def get_site_report(site_id, start_date='15062021', end_date='15062022'):
    '''
    Returns a dataframe of traffic counts on a specified site and date range.
            Parameters:
                    site_id (str): Site's unique id
                    start_date, end_date (str): Strings of the start and end dates of our search ddmmyy
            Returns:
                    report_df (dataframe): Report of traffic counts for that site
                    header (dict): Columns of the dataframe
    '''
    # Download page 1
    report_url = daily_report_query_url(site_id, 1, start_date, end_date)
    with urllib.request.urlopen(report_url) as url:
        report_page = json.loads(url.read().decode())
        
    # Work out how many pages are required    
    header = report_page['Header']
    rows = report_page['Rows']
    row_count = header['row_count']
    total_pages = math.ceil(row_count / 10000)
    # Make a dataframe of the rows so dar
    report_df = pd.DataFrame(data = rows)
    
    for i in range(2, total_pages+1):
        # Get page i of the report
        report_url = daily_report_query_url(site_id, i, start_date, end_date)
        with urllib.request.urlopen(report_url) as url:
            report_page = json.loads(url.read().decode())
        
        rows = report_page['Rows']
        current_page_df = pd.DataFrame(data = rows)
        report_df = pd.concat([report_df, current_page_df], ignore_index=True)

    return report_df, header

# %%
def get_reports_from_sites_df(sites_df, start_date, end_date):
    '''
    Returns a dataframe of traffic counts for an entire set of sites
            Parameters:
                    sites_df (dataframe): The sites we want to query, has the same columns as get_quality_area function's output
                    start_date, end_date (str): Strings of the start and end dates of our search ddmmyy
            Returns:
                    report_df (dataframe): Report of traffic counts for the sites
    '''
    # Get the reports on the site
    train_reports =  collections.defaultdict(str)
    # Go through all the site ids and get reports
    print("sites_df: {}".format(sites_df))
    for site_id in tqdm(sites_df.Id):
        report, header = get_site_report(site_id, start_date, end_date)
        report['site_id'] = site_id
        train_reports[site_id] = report
        
    # Combine reports into one df
    report_df = pd.concat(list(train_reports.values()), ignore_index=True)
    return report_df

# %%
def clean_report(report_df):
    '''
    Cleans the traffic count report with a few key steps:
    1. Format the column names and remove redundant columns
    2. Converts the count columns into intergers
    3. Remove rows with blank data
    4. Remove rows that only report one value (zero)
    5. Add a timestamp column to the report
    
            Parameters:
                    report_df (dataframe): The report of traffic count data outputted by get_reports_from_sites_df
            
            Returns:
                    clean_report_df (datafrane): The cleaned report
    '''
    # Step 1.
    clean_col_names = [
        'site_name',
        'report_date',
        'time_period_ending',
        'time_interval',
        '0-520cm',
        '521-660cm',
        '661-1160cm',
        '1160+cm',
        '0-10mph',
        '11-15mph',
        '16-20mph',
        '21-25mph',
        '26-30mph',
        '31-35mph',
        '36-40mph',
        '41-45mph',
        '46-50mph',
        '51-55mph',
        '56-60mph',
        '61-70mph',
        '71-80mph',
        '80+mph',
        'avg_mph',
        'total_volume',
        'site_id']
    report_df.columns = clean_col_names
    clean_cols = [
         'site_name',
         'site_id',
         'report_date',
         'time_period_ending',
         'time_interval',
         '0-520cm',
         '521-660cm',
         '661-1160cm',
         '1160+cm',
         'avg_mph',
         'total_volume']
    clean_report_df = report_df[clean_cols]
    
    # Steps 2., 3., 4.
    interger_cols = [
         '0-520cm',
         '521-660cm',
         '661-1160cm',
         '1160+cm',
         'total_volume']
    def remove_rows(df):
        df = df.loc[df['total_volume'] != '']  # Remove empty rows
        x = df.groupby('site_id')['total_volume'].nunique()
        zero_sites = list(x[x==1].index)  # Remove sites where the volume is always zero
        df = df.loc[~df.site_id.isin(zero_sites)]
        df[interger_cols] = df[interger_cols].astype('int32')
        return df
    clean_report_df = remove_rows(clean_report_df)
    
    # Step 5.
    def get_timestamp(row):
        year, month,day = row['report_date'].split('T')[0].split('-')
        hour, minute, second = row['time_period_ending'].split(':')
        return datetime.datetime(int(year),int(month),int(day), int(hour), int(minute))
    
    clean_report_df['timestamp'] = clean_report_df.apply(get_timestamp,axis=1)
    return clean_report_df

# %%
# Function used to normalsise the count data
def normalise(clean_report):
    interger_cols = ['0-520cm', '521-660cm', '661-1160cm', '1160+cm', 'total_volume']
    for name in interger_cols:
        new_name = f"{name}_normalised"
        # for ever row in the report present the row's site id's mean volume
        mean = clean_report.groupby('site_id')[name].transform("mean")
        # normalise
        clean_report.loc[:, new_name] = clean_report[name] / mean
        # filter so we don't have rows with a small mean which causes a pole
    return clean_report[mean>1]

# %%
# A pipeline of stages for downloading and normalising reporting.
def download_clean_pipeline(start_date, end_date, max_lat, max_long, min_lat, min_long, quality_threshold = 90, normalise_df=True):
    print('Producing clean report df using following parameters:')
    print('------------------------------------------')
    print('start_date: {}'.format(start_date))
    print('end_date: {}'.format(end_date))
    print('max_lat: {}'.format(max_lat))
    print('max_long: {}'.format(max_long))
    print('min_lat: {}'.format(min_lat))
    print('min_long: {}'.format(min_long))
    print('quality_threshold: {}'.format(quality_threshold))
    print('normalise: {}'.format(normalise_df))
    print('------------------------------------------')

    # Get the quality data
    sites_df = get_quality_area(sites, max_lat, max_long, min_lat, min_long, start_date, end_date, quality_threshold)
    # Download the report
    report_df = get_reports_from_sites_df(sites_df, start_date, end_date)
    # Clean the report
    clean_report_df = clean_report(report_df)
    # Normalsie the report
    if normalise:
        clean_report_df_norm = normalise(clean_report_df)
        return clean_report_df_norm
    else:
        return clean_report_df

# %% [markdown]
# ## Ungrouped Data

# %%
clean_report_df = download_clean_pipeline(START_DATE, END_DATE, MAX_LAT, MAX_LONG, MIN_LAT, MIN_LONG,  QUALITY_THRESHOLD, NORMALISE_DF)
clean_report_df.head()
# Out:
# Producing clean report df using following parameters:
# ------------------------------------------
# start_date: 01062019
# end_date: 15062022
# max_lat: 52.6
# max_long: -0.32
# min_lat: 52.5
# min_long: -0.33
# quality_threshold: 90
# normalise: True
# ------------------------------------------
# 100%|██████████| 3/3 [00:00<00:00,  5.73it/s]
# quality_area_sites_df:      Id                                               Name Description  \
# 0     2  MIDAS site at A1M/2259B priority 1 on link 126...   A1M/2259B
# 1  4466  MIDAS site at A1M/2259A priority 1 on link 199...   A1M/2259A
# 2  7810  TMU Site 6783/1 on link A1 southbound exit for...      6783/1
#
#    Longitude   Latitude  Status
# 0  -0.320275  52.535158  Active
# 1  -0.320531  52.535018  Active
# 2  -0.320749  52.535875  Active
# sites_df:      Id                                               Name Description  \
# 0     2  MIDAS site at A1M/2259B priority 1 on link 126...   A1M/2259B
# 1  4466  MIDAS site at A1M/2259A priority 1 on link 199...   A1M/2259A
# 2  7810  TMU Site 6783/1 on link A1 southbound exit for...      6783/1
#
#    Longitude   Latitude  Status
# 0  -0.320275  52.535158  Active
# 1  -0.320531  52.535018  Active
# 2  -0.320749  52.535875  Active
# 100%|██████████| 3/3 [01:42<00:00, 34.11s/it]
#    site_name site_id          report_date time_period_ending time_interval  \
# 0  A1M/2259B       2  2019-06-01T00:00:00           00:14:00             0
# 1  A1M/2259B       2  2019-06-01T00:00:00           00:29:00             1
# 2  A1M/2259B       2  2019-06-01T00:00:00           00:44:00             2
# 3  A1M/2259B       2  2019-06-01T00:00:00           00:59:00             3
# 4  A1M/2259B       2  2019-06-01T00:00:00           01:14:00             4
#
#    0-520cm  521-660cm  661-1160cm  1160+cm avg_mph  total_volume  \
# 0       24          6           6       16      62            52
# 1       17          3           7       20      60            47
# 2       23          3           3       17      61            46
# 3       12          2           0       19      59            33
# 4       14          5           3       16      61            38
#
#             timestamp  0-520cm_normalised  521-660cm_normalised  \
# 0 2019-06-01 00:14:00            0.259554              0.234373
# 1 2019-06-01 00:29:00            0.183851              0.117186
# 2 2019-06-01 00:44:00            0.248740              0.117186
# 3 2019-06-01 00:59:00            0.129777              0.078124
# 4 2019-06-01 01:14:00            0.151407              0.195311
#
#    661-1160cm_normalised  1160+cm_normalised  total_volume_normalised
# 0               0.445363            0.564074                 0.325197
# 1               0.519590            0.705092                 0.293928
# 2               0.222681            0.599329                 0.287674
# 3               0.000000            0.669838                 0.206375
# 4               0.222681            0.564074                 0.237644

# %%
clean_report_df.describe()
# Out:
#              0-520cm      521-660cm     661-1160cm        1160+cm  \
# count  316194.000000  316194.000000  316194.000000  316194.000000
# mean       77.271586      18.194061       9.375542      20.397825
# std        75.031979      21.118919      10.680899      19.356200
# min         0.000000       0.000000       0.000000       0.000000
# 25%        15.000000       3.000000       2.000000       6.000000
# 50%        55.000000       8.000000       5.000000      13.000000
# 75%       120.000000      31.000000      14.000000      32.000000
# max       580.000000     158.000000      81.000000     142.000000
#
#         total_volume  0-520cm_normalised  521-660cm_normalised  \
# count  316194.000000       316194.000000         316194.000000
# mean      125.238676            1.000000              1.000000
# std       113.564047            0.867800              0.944294
# min         0.000000            0.000000              0.000000
# 25%        31.000000            0.205481              0.205593
# 50%        87.000000            0.812390              0.703118
# 75%       207.000000            1.600887              1.602277
# max       716.000000            6.546909              7.782487
#
#        661-1160cm_normalised  1160+cm_normalised  total_volume_normalised
# count          316194.000000       316194.000000            316194.000000
# mean                1.000000            1.000000                 1.000000
# std                 1.015015            0.755598                 0.774218
# min                 0.000000            0.000000                 0.000000
# 25%                 0.222681            0.381704                 0.265487
# 50%                 0.556801            0.763408                 0.872315
# 75%                 1.645197            1.586458                 1.619731
# max                 8.908821            6.790712                 5.040551

# %% [markdown]
# ## Preprocessing and saving data

# %% [markdown]
# ### Save full clean report

# %%
print("Counting na values: {}".format(clean_report_df.isna().sum()))
os.makedirs('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data', exist_ok=True)  
clean_report_df.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/clean_report.csv')
# Out:
# Counting na values: site_name                  0
# site_id                    0
# report_date                0
# time_period_ending         0
# time_interval              0
# 0-520cm                    0
# 521-660cm                  0
# 661-1160cm                 0
# 1160+cm                    0
# avg_mph                    0
# total_volume               0
# timestamp                  0
# 0-520cm_normalised         0
# 521-660cm_normalised       0
# 661-1160cm_normalised      0
# 1160+cm_normalised         0
# total_volume_normalised    0
# dtype: int64

# %% [markdown]
# ### Save site_id, timestamp

# %%
def dt64_to_float(dt64):
    """
    year = dt64.astype('M8[Y]')
    print("year: {}".format(year))
    days = (dt64 - year).astype('timedelta64[D]')
    print("days: {}".format(days))
    year_next = year + np.timedelta64(1, 'Y')
    days_of_year = (year_next.astype('M8[D]') - year.astype('M8[D]')).astype('timedelta64[D]')
    print("days_of_year: {}".format(days_of_year))
    dt_float = 1970 + year.astype(float) + days / (days_of_year)
    print("dt_float: {}".format(dt_float))
    """
    dt_float = dt64.values.astype('float64')
    dt_float = ((dt_float)-dt_float.min())/(dt_float.max()-dt_float.min())
    print(dt_float)
    return dt_float

# %%
os.makedirs('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data', exist_ok=True)  
timestamp_df = pd.DataFrame(clean_report_df[['site_id', 'timestamp']], index=clean_report_df.index)

timestamp_df['timestamp'] = dt64_to_float(timestamp_df['timestamp'])
timestamp_df['timestamp'] = ((timestamp_df['timestamp'])-timestamp_df['timestamp'].min())/(timestamp_df['timestamp'].max()-timestamp_df['timestamp'].min())

timestamp_df.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/timestamp.csv')
# Out:
# [1.55934804e+18 1.55934894e+18 1.55934984e+18 ... 1.65533574e+18
#  1.65533664e+18 1.65533754e+18]

# %% [markdown]
# ### Save site_id, avg_mph

# %%
os.makedirs('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data', exist_ok=True)  
avg_mph_df = pd.DataFrame(clean_report_df[['site_id', 'avg_mph']], index=clean_report_df.index)
avg_mph_df.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/avg_mph.csv')

# %% [markdown]
# ### Save site_id, total_volume

# %%
os.makedirs('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data', exist_ok=True)  
total_volume_df = pd.DataFrame(clean_report_df[['site_id', 'total_volume']], index=clean_report_df.index)
total_volume_df.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/total_volume.csv')

# %% [markdown]
# ### Save site_id, total_volume_normalised

# %%
os.makedirs('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data', exist_ok=True)  
total_volume_normalised_df = pd.DataFrame(clean_report_df[['site_id', 'total_volume_normalised']], index=clean_report_df.index)
total_volume_normalised_df.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/total_volume_normalised.csv')

# %% [markdown]
# ## Grouped Data

# %%
# Groupby site_id and report_date
dfs = [site_day for _, site_day in clean_report_df.groupby(['site_id', 'report_date'])]

print(len(dfs))
"""
dfs_site_daily_count = []
for i, df in enumerate(dfs):
    print(i, df['site_id'])
    if i > 5:
        break
    daily_count = df['total_volume'].sum()
    df['daily_count'] = daily_count
    #df.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/{}_{}.csv'.format(df['site_id'], df['report_date']))  
"""

dfs[0].head()
df_site_day = dfs[0]
df_site_day['daily_count'] = df_site_day['total_volume'].sum()

df_site_day['report_date'] = pd.to_datetime(df_site_day['report_date'], infer_datetime_format=True)
df_site_day['month'] = df_site_day['report_date'].dt.month
df_site_day['day'] = df_site_day['report_date'].dt.day
df_site_day['hour'] = df_site_day['timestamp'].dt.hour

# timestamp preprocessing
df_site_day['timestamp_min_max'] = dt64_to_float(df_site_day['timestamp'])
df_site_day.to_csv('/home/ah2719/FYP/Spatial_Finance_Transport/data/ground_truth_data/report_daily_count.csv')  

df_site_day.head()
# Out:
# 3310
# [0.         0.01052632 0.02105263 0.03157895 0.04210526 0.05263158
#  0.06315789 0.07368421 0.08421053 0.09473684 0.10526316 0.11578947
#  0.12631579 0.13684211 0.14736842 0.15789474 0.16842105 0.17894737
#  0.18947368 0.2        0.21052632 0.22105263 0.23157895 0.24210526
#  0.25263158 0.26315789 0.27368421 0.28421053 0.29473684 0.30526316
#  0.31578947 0.32631579 0.33684211 0.34736842 0.35789474 0.36842105
#  0.37894737 0.38947368 0.4        0.41052632 0.42105263 0.43157895
#  0.44210526 0.45263158 0.46315789 0.47368421 0.48421053 0.49473684
#  0.50526316 0.51578947 0.52631579 0.53684211 0.54736842 0.55789474
#  0.56842105 0.57894737 0.58947368 0.6        0.61052632 0.62105263
#  0.63157895 0.64210526 0.65263158 0.66315789 0.67368421 0.68421053
#  0.69473684 0.70526316 0.71578947 0.72631579 0.73684211 0.74736842
#  0.75789474 0.76842105 0.77894737 0.78947368 0.8        0.81052632
#  0.82105263 0.83157895 0.84210526 0.85263158 0.86315789 0.87368421
#  0.88421053 0.89473684 0.90526316 0.91578947 0.92631579 0.93684211
#  0.94736842 0.95789474 0.96842105 0.97894737 0.98947368 1.        ]
#    site_name site_id report_date time_period_ending time_interval  0-520cm  \
# 0  A1M/2259B       2  2019-06-01           00:14:00             0       24
# 1  A1M/2259B       2  2019-06-01           00:29:00             1       17
# 2  A1M/2259B       2  2019-06-01           00:44:00             2       23
# 3  A1M/2259B       2  2019-06-01           00:59:00             3       12
# 4  A1M/2259B       2  2019-06-01           01:14:00             4       14
#
#    521-660cm  661-1160cm  1160+cm avg_mph  ...  0-520cm_normalised  \
# 0          6           6       16      62  ...            0.259554
# 1          3           7       20      60  ...            0.183851
# 2          3           3       17      61  ...            0.248740
# 3          2           0       19      59  ...            0.129777
# 4          5           3       16      61  ...            0.151407
#
#   521-660cm_normalised  661-1160cm_normalised  1160+cm_normalised  \
# 0             0.234373               0.445363            0.564074
# 1             0.117186               0.519590            0.705092
# 2             0.117186               0.222681            0.599329
# 3             0.078124               0.000000            0.669838
# 4             0.195311               0.222681            0.564074
#
#    total_volume_normalised  daily_count  month  day  hour  timestamp_min_max
# 0                 0.325197        16392      6    1     0           0.000000
# 1                 0.293928        16392      6    1     0           0.010526
# 2                 0.287674        16392      6    1     0           0.021053
# 3                 0.206375        16392      6    1     0           0.031579
# 4                 0.237644        16392      6    1     1           0.042105
#
# [5 rows x 22 columns]
