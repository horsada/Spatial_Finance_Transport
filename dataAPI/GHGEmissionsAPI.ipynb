# %% [markdown]
# # GHG Emissions API

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Global Variables

# %%
GHG_DATA_PATH = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/1087005/uk-local-authority-ghg-emissions-2020-dataset.csv'
LOCAL_AUTHORITY = 'Bolsover'
YEAR = 2018

# %% [markdown]
# ## General Functions

# %% [markdown]
# ## Data

# %%
df = pd.read_csv(GHG_DATA_PATH)
df.head()
# Out:
#    Country Country Code         Region Region Code Second Tier Authority  \
# 0  England    E92000001  East Midlands   E12000004                 Derby
# 1  England    E92000001  East Midlands   E12000004                 Derby
# 2  England    E92000001  East Midlands   E12000004                 Derby
# 3  England    E92000001  East Midlands   E12000004                 Derby
# 4  England    E92000001  East Midlands   E12000004                 Derby
#
#   Local Authority Local Authority Code  Calendar Year LA GHG Sector  \
# 0           Derby            E06000015           2005   Agriculture
# 1           Derby            E06000015           2005   Agriculture
# 2           Derby            E06000015           2005   Agriculture
# 3           Derby            E06000015           2005   Agriculture
# 4           Derby            E06000015           2005   Agriculture
#
#          LA GHG Sub-sector Greenhouse gas  Territorial emissions (kt CO2e)  \
# 0  Agriculture Electricity            CH4                         0.010737
# 1  Agriculture Electricity            CO2                         0.380289
# 2  Agriculture Electricity            N2O                         0.001710
# 3          Agriculture Gas            CH4                         0.021121
# 4          Agriculture Gas            CO2                         0.700438
#
#    CO2 emissions within the scope of influence of LAs (kt CO2e)  \
# 0                                           0.000000
# 1                                           0.380289
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.700438
#
#    Mid-year Population (thousands)  Area (km2)
# 0                           236.47     78.0311
# 1                           236.47     78.0311
# 2                           236.47     78.0311
# 3                           236.47     78.0311
# 4                           236.47     78.0311

# %%
df.dtypes
# Out:
# Country                                                          object
# Country Code                                                     object
# Region                                                           object
# Region Code                                                      object
# Second Tier Authority                                            object
# Local Authority                                                  object
# Local Authority Code                                             object
# Calendar Year                                                     int64
# LA GHG Sector                                                    object
# LA GHG Sub-sector                                                object
# Greenhouse gas                                                   object
# Territorial emissions (kt CO2e)                                 float64
# CO2 emissions within the scope of influence of LAs (kt CO2e)    float64
# Mid-year Population (thousands)                                 float64
# Area (km2)                                                      float64
# dtype: object

# %%
# Filter by road transport
df = df.loc[df['LA GHG Sector'] == "Transport"]
df = df[df['LA GHG Sub-sector'].str.contains("Road")]
df.head()
# Out:
#     Country Country Code         Region Region Code Second Tier Authority  \
# 65  England    E92000001  East Midlands   E12000004                 Derby
# 66  England    E92000001  East Midlands   E12000004                 Derby
# 67  England    E92000001  East Midlands   E12000004                 Derby
# 68  England    E92000001  East Midlands   E12000004                 Derby
# 69  England    E92000001  East Midlands   E12000004                 Derby
#
#    Local Authority Local Authority Code  Calendar Year LA GHG Sector  \
# 65           Derby            E06000015           2005     Transport
# 66           Derby            E06000015           2005     Transport
# 67           Derby            E06000015           2005     Transport
# 68           Derby            E06000015           2005     Transport
# 69           Derby            E06000015           2005     Transport
#
#                LA GHG Sub-sector Greenhouse gas  \
# 65      Road Transport (A roads)            CH4
# 66      Road Transport (A roads)            CO2
# 67      Road Transport (A roads)            N2O
# 68  Road Transport (Minor roads)            CH4
# 69  Road Transport (Minor roads)            CO2
#
#     Territorial emissions (kt CO2e)  \
# 65                         2.041521
# 66                       212.296075
# 67                         2.519068
# 68                         3.246193
# 69                       293.002134
#
#     CO2 emissions within the scope of influence of LAs (kt CO2e)  \
# 65                                           0.000000
# 66                                         212.296075
# 67                                           0.000000
# 68                                           0.000000
# 69                                         293.002134
#
#     Mid-year Population (thousands)  Area (km2)
# 65                           236.47     78.0311
# 66                           236.47     78.0311
# 67                           236.47     78.0311
# 68                           236.47     78.0311
# 69                           236.47     78.0311

# %% [markdown]
# ## Analyse df

# %%
print("GHG's: {}".format(df['Greenhouse gas'].unique()))
print("Road transport types: {}".format(df['LA GHG Sub-sector'].unique()))
# Out:
# GHG's: ['CH4' 'CO2' 'N2O']
# Road transport types: ['Road Transport (A roads)' 'Road Transport (Minor roads)'
#  'Road Transport (Motorways)']

# %% [markdown]
# ## Motorways

# %%
df_motorway = df.loc[df['LA GHG Sub-sector'] == "Road Transport (Motorways)"]
df_motorway.head()
# Out:
#       Country Country Code         Region Region Code Second Tier Authority  \
# 2477  England    E92000001  East Midlands   E12000004            Derbyshire
# 2478  England    E92000001  East Midlands   E12000004            Derbyshire
# 2479  England    E92000001  East Midlands   E12000004            Derbyshire
# 2556  England    E92000001  East Midlands   E12000004            Derbyshire
# 2557  England    E92000001  East Midlands   E12000004            Derbyshire
#
#      Local Authority Local Authority Code  Calendar Year LA GHG Sector  \
# 2477        Bolsover            E07000033           2005     Transport
# 2478        Bolsover            E07000033           2005     Transport
# 2479        Bolsover            E07000033           2005     Transport
# 2556        Bolsover            E07000033           2006     Transport
# 2557        Bolsover            E07000033           2006     Transport
#
#                LA GHG Sub-sector Greenhouse gas  \
# 2477  Road Transport (Motorways)            CH4
# 2478  Road Transport (Motorways)            CO2
# 2479  Road Transport (Motorways)            N2O
# 2556  Road Transport (Motorways)            CH4
# 2557  Road Transport (Motorways)            CO2
#
#       Territorial emissions (kt CO2e)  \
# 2477                         1.009594
# 2478                       227.140738
# 2479                         1.333054
# 2556                         0.948244
# 2557                       224.946955
#
#       CO2 emissions within the scope of influence of LAs (kt CO2e)  \
# 2477                                                0.0
# 2478                                                0.0
# 2479                                                0.0
# 2556                                                0.0
# 2557                                                0.0
#
#       Mid-year Population (thousands)  Area (km2)
# 2477                           73.844    160.3347
# 2478                           73.844    160.3347
# 2479                           73.844    160.3347
# 2556                           74.347    160.3347
# 2557                           74.347    160.3347

# %% [markdown]
# ### Total GHG Emissions by Local Authority and Year

# %%
df_motorway = pd.DataFrame(df_motorway.groupby(by=['Local Authority', 'Calendar Year'])['Territorial emissions (kt CO2e)'].sum())
df_motorway = df_motorway.reset_index(level=['Local Authority', 'Calendar Year'])
df_motorway.head()
# Out:
#            Local Authority  Calendar Year  Territorial emissions (kt CO2e)
# 0  Antrim and Newtownabbey           2005                       105.154184
# 1  Antrim and Newtownabbey           2006                       104.037523
# 2  Antrim and Newtownabbey           2007                       104.199617
# 3  Antrim and Newtownabbey           2008                       101.315233
# 4  Antrim and Newtownabbey           2009                        99.998182

# %% [markdown]
# ### Filter by Local Authority and Year

# %%
# Use Global Variables defined
df_motorway = df_motorway.loc[df_motorway['Local Authority'] == LOCAL_AUTHORITY]
df_motorway = df_motorway.loc[df_motorway['Calendar Year'] == YEAR]
df_motorway
# Out:
#     Local Authority  Calendar Year  Territorial emissions (kt CO2e)
# 221        Bolsover           2018                       195.526434
